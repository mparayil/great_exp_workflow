# %%
import os
import json
import sys
import great_expectations as ge
import great_expectations.jupyter_ux
from datetime import datetime
import math
import pandas as pd
os.chdir('/Users/mparayil/Desktop/Development/dsa-data-workflows/grtexp_agero_dsa/great_expectations')
# Out:
# 2020-02-24T13:37:16-0500 - INFO - Great Expectations logging enabled at INFO level by JupyterUX module.

# %%
import ge_prod.ge_data_access as gda
import ge_prod.queries as queries

# %%
rule_query = queries.queries.get('network_claims').get('create_expectations_2019Q4')

# %%
rule_query
# Out:
# "SELECT * FROM network_claims WHERE modified_date_utc >= to_date('2019-10-01') and modified_date_utc <= to_date('2019-12-31');"

# %% [markdown]
# # Author Expectations

# %% [markdown]
# [**Watch a short tutorial video**](https://docs.greatexpectations.io/en/latest/getting_started/create_expectations.html?utm_source=notebook&utm_medium=create_expectations#video)
#
# [**Read more in the tutorial**](https://docs.greatexpectations.io/en/latest/getting_started/create_expectations.html?utm_source=notebook&utm_medium=create_expectations)
#
# **Reach out for help on** [**Great Expectations Slack**](https://tinyurl.com/great-expectations-slack)

# %% [markdown]
# ### Get a DataContext object
# [Read more in the tutorial](https://great-expectations.readthedocs.io/en/latest/getting_started/create_expectations.html?utm_source=notebook&utm_medium=create_expectations#get-datacontext-object)

# %%
context = ge.data_context.DataContext()
# Out:
# 2020-02-24T13:37:23-0500 - INFO - Using project config: /Users/mparayil/Desktop/Development/dsa-data-workflows/grtexp_agero_dsa/great_expectations/great_expectations.yml

# %% [markdown]
# ### List data assets in your project
#
# [Read more in the tutorial](https://docs.greatexpectations.io/en/latest/getting_started/create_expectations.html?utm_source=notebook&utm_medium=create_expectations#data-assets)

# %%
great_expectations.jupyter_ux.list_available_data_asset_names(context)
# Out:
# Inspecting your data sources. This may take a moment...
# <p>No data assets found in this data source.</p>
# <p>Read about how generators derive data assets from data sources:
# <a href="https://great-expectations.readthedocs.io/en/latest/how_to_add_data_source.html">Data assets</a>
# </p>
# <h2 style='margin: 0'>Datasource: agero_dsa_pandas (PandasDatasource)</h2>generator: default (SubdirReaderGenerator)

# %% [markdown]
# #### Pick one of the data asset names above and use as the value of data_asset_name argument below
#
# [Read more in the tutorial](https://docs.greatexpectations.io/en/latest/getting_started/create_expectations.html?utm_source=notebook&utm_medium=create_expectations#get-batch)

# %% [markdown]
# ### Specify data_asset & expectation_suite_name

# %%
data_asset_name = 'network_claims'
normalized_data_asset_name = context.normalize_data_asset_name(data_asset_name)
print(normalized_data_asset_name)
# Out:
# NormalizedDataAssetName(datasource='agero_dsa_pandas', generator='default', generator_asset='network_claims')

# %% [markdown]
# ### Create a new empty expectation suite

# %%
expectation_suite_name = 'warnings_2019Q4'
context.create_expectation_suite(data_asset_name=data_asset_name, expectation_suite_name=expectation_suite_name,
                                overwrite_existing=True)
# Out:
# {'data_asset_name': 'agero_dsa_pandas/default/network_claims',
#  'expectation_suite_name': 'warnings_2019Q4',
#  'meta': {'great_expectations.__version__': '0.8.8'},
#  'expectations': []}

# %%
context.list_expectation_suite_keys()
# Out:
# [{'data_asset_name': agero_dsa_pandas/default/network_outreach,
#   'expectation_suite_name': 'warnings_2019Q4'},
#  {'data_asset_name': agero_dsa_pandas/default/network_outreach,
#   'expectation_suite_name': 'warnings'},
#  {'data_asset_name': agero_dsa_pandas/default/network_claims,
#   'expectation_suite_name': 'warnings_2019Q4'},
#  {'data_asset_name': agero_dsa_pandas/default/network_claims,
#   'expectation_suite_name': 'warnings_2019dec'}]

# %% [markdown]
# ### Get batch to create expectations against

# %%
rule_df = gda.snowflake_connector_to_df(rule_query)
# rule_df.to_pickle('temp_data/network_claims_2019Q4.pkl')

# %%
# pickle_df = pd.read_pickle('temp_data/network_claims_2019Q4.pkl')

# %%
b_kwargs = {"dataset": rule_df}
batch = context.get_batch(normalized_data_asset_name, expectation_suite_name=expectation_suite_name,
                         batch_kwargs=b_kwargs)

# %%
batch.get_row_count()
# Out:
# 2678943

# %%
print(rule_df.shape)
# Out:
# (2678943, 39)

# %%
[datasource['name'] for datasource in context.list_datasources() if datasource['class_name'] == 'PandasDatasource']
# Out:
# ['agero_dsa_pandas']

# %%
# getting rule_df batchId & fingerprint
rule_batch_fingerprint = batch.batch_fingerprint
rule_batch_id = batch.batch_id

# %%
print('rule_batch_fingerprint: ', rule_batch_fingerprint, sep='\n')
print('rule_batch_id: ', rule_batch_id, sep='\n')
# Out:
# rule_batch_fingerprint:
# {'partition_id': '20200224T183814.055708Z', 'fingerprint': 'afa0a1402df775cdc86068bc697680a0'}
# rule_batch_id:
# {'timestamp': 1582569491.5552058, 'PandasInMemoryDF': True, 'fingerprint': '7303977713c3205caa9594effecc1260'}

# %% [markdown]
# ## Author Expectations
#
# [Read more in the tutorial](https://docs.greatexpectations.io/en/latest/getting_started/create_expectations.html?utm_source=notebook&utm_medium=create_expectations#create-expectations)
#
# See available expectations in the [expectation glossary](https://docs.greatexpectations.io/en/latest/glossary.html?utm_source=notebook&utm_medium=create_expectations)

# %% [markdown]
# ### Dataset exploration & understanding of fields to ensure rules reflect behavior of data
# - Validating columns to exist in table shape
# - Expected column count in table shape
# - Expected set values to be seen in given column
# - Expected columns to have null or non-null values X percentage of the time
# - Expect column values to be of certain data type(s)
# - Placing max and min values limits on numerical columns
# - Average or median column value to be within a certain range
# - Expecting column A to be large/less than column B

# %% [markdown]
# ### 1. Validating to see if every column exists in table

# %%
# add more expectations here
column_names = batch.get_table_columns()
print(column_names)
# Out:
# ['CASE_ID', 'TASK_ID', 'VENDOR_ID', 'CLAIM_ID', 'VENDOR_ADDRESS_ID', 'CLAIM_PO_NUMBER_ENTERED', 'ORIGINAL_CLAIM_PAYMENT_AMOUNT', 'ORIGINAL_CLAIM_STATUS_CODE', 'ORIGINAL_CLAIM_TYPE_CODE', 'SUBMITTED_CLAIM_AMOUNT', 'SUBMITTED_TOW_MILES', 'SUBMITTED_ENROUTE_MILES', 'SUBMITTED_LABOR_HOURS', 'SERVICE_ID', 'WAS_AUDITED', 'ADDCHARGE_AMOUNT', 'IS_CLAIM_APPROVED', 'ORIGINAL_CLAIM_APPROVED_PAYMENT', 'ADDCHARGE_DETAILS', 'ADDCHARGE_COUNT', 'BASE_TOTAL_FROM_RATES', 'ADDPAY_DETAILS', 'ADDPAY_COUNT', 'ADDPAY_PAYMENT_AMOUNT', 'ADDPAY_APPROVED_PAYMENT', 'COMPLETE_APPROVED_PAYMENT', 'IS_VCC', 'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN', 'ORIGINAL_CLAIM_APPROVED_DATE_UTC', 'SERVICE_DATE_EASTERN', 'SERVICE_DATE_UTC', 'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN', 'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC', 'ADDPAY_APPROVED_DATE_EASTERN', 'ADDPAY_APPROVED_DATE_UTC', 'ADDPAY_SUBMITTED_DATE_EASTERN', 'ADDPAY_SUBMITTED_DATE_UTC', 'MODIFIED_DATE_EASTERN', 'MODIFIED_DATE_UTC']

# %%
# columns with multipe data types, will be changing them to int types in future
# case_id, po_number, vendor_id

# %%
master_column_names = ['ADDCHARGE_AMOUNT', 'ADDCHARGE_COUNT', 'ADDCHARGE_DETAILS',
                        'ADDPAY_APPROVED_DATE_EASTERN', 'ADDPAY_APPROVED_DATE_UTC',
                        'ADDPAY_APPROVED_PAYMENT', 'ADDPAY_COUNT', 'ADDPAY_DETAILS',
                        'ADDPAY_PAYMENT_AMOUNT', 'ADDPAY_SUBMITTED_DATE_EASTERN', 'ADDPAY_SUBMITTED_DATE_UTC',
                        'BASE_TOTAL_FROM_RATES', 'CASE_ID', 'CLAIM_ID',
                        'CLAIM_PO_NUMBER_ENTERED', 'COMPLETE_APPROVED_PAYMENT',  'IS_CLAIM_APPROVED', 'IS_VCC',
                        'MODIFIED_DATE_EASTERN', 'MODIFIED_DATE_UTC', 'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN',
                        'ORIGINAL_CLAIM_APPROVED_DATE_UTC', 'ORIGINAL_CLAIM_APPROVED_PAYMENT',
                        'ORIGINAL_CLAIM_PAYMENT_AMOUNT', 'ORIGINAL_CLAIM_STATUS_CODE',
                        'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN',
                        'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC', 'ORIGINAL_CLAIM_TYPE_CODE',
                        'SERVICE_DATE_EASTERN', 'SERVICE_DATE_UTC', 'SERVICE_ID',
                        'SUBMITTED_CLAIM_AMOUNT', 'SUBMITTED_ENROUTE_MILES',
                        'SUBMITTED_LABOR_HOURS', 'SUBMITTED_TOW_MILES', 'TASK_ID',
                        'VENDOR_ADDRESS_ID', 'VENDOR_ID', 'WAS_AUDITED']

# %%
len(master_column_names)
# Out:
# 39

# %%
len(column_names)
# Out:
# 39

# %%
# Ensuring columns to exist
for col in master_column_names:
    print(col + ':', batch.expect_column_to_exist(col, result_format='BASIC', catch_exceptions=True), sep='\n')
# Out:
# ADDCHARGE_AMOUNT:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDCHARGE_COUNT:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDCHARGE_DETAILS:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_APPROVED_DATE_EASTERN:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_APPROVED_DATE_UTC:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_APPROVED_PAYMENT:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_COUNT:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_DETAILS:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_PAYMENT_AMOUNT:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_SUBMITTED_DATE_EASTERN:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_SUBMITTED_DATE_UTC:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# BASE_TOTAL_FROM_RATES:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# CASE_ID:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# CLAIM_ID:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# CLAIM_PO_NUMBER_ENTERED:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# COMPLETE_APPROVED_PAYMENT:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# IS_CLAIM_APPROVED:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# IS_VCC:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# MODIFIED_DATE_EASTERN:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# MODIFIED_DATE_UTC:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_APPROVED_DATE_EASTERN:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_APPROVED_DATE_UTC:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_APPROVED_PAYMENT:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_PAYMENT_AMOUNT:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_STATUS_CODE:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_SUBMITTED_DATE_UTC:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_TYPE_CODE:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SERVICE_DATE_EASTERN:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SERVICE_DATE_UTC:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SERVICE_ID:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SUBMITTED_CLAIM_AMOUNT:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SUBMITTED_ENROUTE_MILES:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SUBMITTED_LABOR_HOURS:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SUBMITTED_TOW_MILES:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# TASK_ID:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# VENDOR_ADDRESS_ID:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# VENDOR_ID:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# WAS_AUDITED:
# {'success': True, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}

# %% [markdown]
# ### 2. Validating column count in table is always the same

# %%
print('# of columns in network_claims: ', len(column_names))
# Out:
# # of columns in network_claims:  39

# %%
print('# of columns in {}: '.format('network_claims'), len(master_column_names), '\n')
if len(column_names) == len(master_column_names):
    print(batch.expect_table_column_count_to_equal(len(column_names), result_format='SUMMARY'))
else:
    print(batch.expect_table_column_count_to_equal(len(master_column_names), result_format='SUMMARY'))
# Out:
# # of columns in network_claims:  39
#
# {'success': True, 'result': {'observed_value': 39}}

# %% [markdown]
# ### 3. Checking which columns should not have null values

# %%
# identifying which columns should not be null
print(column_names)
# Out:
# ['CASE_ID', 'TASK_ID', 'VENDOR_ID', 'CLAIM_ID', 'VENDOR_ADDRESS_ID', 'CLAIM_PO_NUMBER_ENTERED', 'ORIGINAL_CLAIM_PAYMENT_AMOUNT', 'ORIGINAL_CLAIM_STATUS_CODE', 'ORIGINAL_CLAIM_TYPE_CODE', 'SUBMITTED_CLAIM_AMOUNT', 'SUBMITTED_TOW_MILES', 'SUBMITTED_ENROUTE_MILES', 'SUBMITTED_LABOR_HOURS', 'SERVICE_ID', 'WAS_AUDITED', 'ADDCHARGE_AMOUNT', 'IS_CLAIM_APPROVED', 'ORIGINAL_CLAIM_APPROVED_PAYMENT', 'ADDCHARGE_DETAILS', 'ADDCHARGE_COUNT', 'BASE_TOTAL_FROM_RATES', 'ADDPAY_DETAILS', 'ADDPAY_COUNT', 'ADDPAY_PAYMENT_AMOUNT', 'ADDPAY_APPROVED_PAYMENT', 'COMPLETE_APPROVED_PAYMENT', 'IS_VCC', 'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN', 'ORIGINAL_CLAIM_APPROVED_DATE_UTC', 'SERVICE_DATE_EASTERN', 'SERVICE_DATE_UTC', 'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN', 'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC', 'ADDPAY_APPROVED_DATE_EASTERN', 'ADDPAY_APPROVED_DATE_UTC', 'ADDPAY_SUBMITTED_DATE_EASTERN', 'ADDPAY_SUBMITTED_DATE_UTC', 'MODIFIED_DATE_EASTERN', 'MODIFIED_DATE_UTC']

# %%
rule_df.isnull().sum()
# Out:
# CASE_ID                                        0
# TASK_ID                                        0
# VENDOR_ID                                      0
# CLAIM_ID                                       0
# VENDOR_ADDRESS_ID                           5435
# CLAIM_PO_NUMBER_ENTERED                     2646
# ORIGINAL_CLAIM_PAYMENT_AMOUNT                  0
# ORIGINAL_CLAIM_STATUS_CODE                     0
# ORIGINAL_CLAIM_TYPE_CODE                       0
# SUBMITTED_CLAIM_AMOUNT                         0
# SUBMITTED_TOW_MILES                        58878
# SUBMITTED_ENROUTE_MILES                    15740
# SUBMITTED_LABOR_HOURS                     167879
# SERVICE_ID                                     0
# WAS_AUDITED                                    0
# ADDCHARGE_AMOUNT                         2157721
# IS_CLAIM_APPROVED                              0
# ORIGINAL_CLAIM_APPROVED_PAYMENT                0
# ADDCHARGE_DETAILS                        2157721
# ADDCHARGE_COUNT                                0
# BASE_TOTAL_FROM_RATES                     932307
# ADDPAY_DETAILS                           2573487
# ADDPAY_COUNT                             2573487
# ADDPAY_PAYMENT_AMOUNT                    2573488
# ADDPAY_APPROVED_PAYMENT                  2573488
# COMPLETE_APPROVED_PAYMENT                      0
# IS_VCC                                         0
# ORIGINAL_CLAIM_APPROVED_DATE_EASTERN       64501
# ORIGINAL_CLAIM_APPROVED_DATE_UTC           64501
# SERVICE_DATE_EASTERN                         211
# SERVICE_DATE_UTC                             211
# ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN       3446
# ORIGINAL_CLAIM_SUBMITTED_DATE_UTC           3446
# ADDPAY_APPROVED_DATE_EASTERN             2578916
# ADDPAY_APPROVED_DATE_UTC                 2578916
# ADDPAY_SUBMITTED_DATE_EASTERN            2573491
# ADDPAY_SUBMITTED_DATE_UTC                2573491
# MODIFIED_DATE_EASTERN                          0
# MODIFIED_DATE_UTC                              0
# dtype: int64

# %%
# Separating null & non-null columns
null_cols = list(batch.isnull().sum()[batch.isnull().sum() > 0].keys())
not_null_cols = list(batch.isnull().sum()[batch.isnull().sum() == 0].keys())

# %%
not_null_cols
# Out:
# ['CASE_ID',
#  'TASK_ID',
#  'VENDOR_ID',
#  'CLAIM_ID',
#  'ORIGINAL_CLAIM_PAYMENT_AMOUNT',
#  'ORIGINAL_CLAIM_STATUS_CODE',
#  'ORIGINAL_CLAIM_TYPE_CODE',
#  'SUBMITTED_CLAIM_AMOUNT',
#  'SERVICE_ID',
#  'WAS_AUDITED',
#  'IS_CLAIM_APPROVED',
#  'ORIGINAL_CLAIM_APPROVED_PAYMENT',
#  'ADDCHARGE_COUNT',
#  'COMPLETE_APPROVED_PAYMENT',
#  'IS_VCC',
#  'MODIFIED_DATE_EASTERN',
#  'MODIFIED_DATE_UTC']

# %%
# checking for all columns that shouldn't be null are not
for col in not_null_cols:
    print(col, '\n', batch.expect_column_values_to_not_be_null(col, result_format='BASIC'))
# Out:
# CASE_ID
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# TASK_ID
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# VENDOR_ID
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# CLAIM_ID
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# ORIGINAL_CLAIM_PAYMENT_AMOUNT
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# ORIGINAL_CLAIM_STATUS_CODE
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# ORIGINAL_CLAIM_TYPE_CODE
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# SUBMITTED_CLAIM_AMOUNT
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# SERVICE_ID
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# WAS_AUDITED
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# IS_CLAIM_APPROVED
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# ORIGINAL_CLAIM_APPROVED_PAYMENT
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# ADDCHARGE_COUNT
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# COMPLETE_APPROVED_PAYMENT
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# IS_VCC
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# MODIFIED_DATE_EASTERN
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}
# MODIFIED_DATE_UTC
#  {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'partial_unexpected_list': []}}

# %%
print(f"capturing the following columns to not be null: \n {not_null_cols}")
# Out:
# capturing the following columns to not be null:
#  ['CASE_ID', 'TASK_ID', 'VENDOR_ID', 'CLAIM_ID', 'ORIGINAL_CLAIM_PAYMENT_AMOUNT', 'ORIGINAL_CLAIM_STATUS_CODE', 'ORIGINAL_CLAIM_TYPE_CODE', 'SUBMITTED_CLAIM_AMOUNT', 'SERVICE_ID', 'WAS_AUDITED', 'IS_CLAIM_APPROVED', 'ORIGINAL_CLAIM_APPROVED_PAYMENT', 'ADDCHARGE_COUNT', 'COMPLETE_APPROVED_PAYMENT', 'IS_VCC', 'MODIFIED_DATE_EASTERN', 'MODIFIED_DATE_UTC']

# %%
null_cols
# Out:
# ['VENDOR_ADDRESS_ID',
#  'CLAIM_PO_NUMBER_ENTERED',
#  'SUBMITTED_TOW_MILES',
#  'SUBMITTED_ENROUTE_MILES',
#  'SUBMITTED_LABOR_HOURS',
#  'ADDCHARGE_AMOUNT',
#  'ADDCHARGE_DETAILS',
#  'BASE_TOTAL_FROM_RATES',
#  'ADDPAY_DETAILS',
#  'ADDPAY_COUNT',
#  'ADDPAY_PAYMENT_AMOUNT',
#  'ADDPAY_APPROVED_PAYMENT',
#  'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN',
#  'ORIGINAL_CLAIM_APPROVED_DATE_UTC',
#  'SERVICE_DATE_EASTERN',
#  'SERVICE_DATE_UTC',
#  'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN',
#  'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC',
#  'ADDPAY_APPROVED_DATE_EASTERN',
#  'ADDPAY_APPROVED_DATE_UTC',
#  'ADDPAY_SUBMITTED_DATE_EASTERN',
#  'ADDPAY_SUBMITTED_DATE_UTC']

# %%
len(null_cols)
# Out:
# 22

# %% [markdown]
# ### 4. Validating columns to have null values
# - **columns to check:**
#     - VENDOR_ADDRESS_ID
#     - CLAIM_PO_NUMBER_ENTERED
#     - SUBMITTED_TOW_MILES
#     - SUBMITTED_ENROUTE_MILES
#     - SUBMITTED_LABOR_HOURS
#     - ADDCHARGE_AMOUNT
#     - ADDCHARGE_DETAILS
#     - BASE_TOTAL_FROM_RATES
#     - ADDPAY_DETAILS
#     - ADDPAY_COUNT
#     - ADDPAY_PAYMENT_AMOUNT
#     - ADDPAY_APPROVED_PAYMENT
#     - ORIGINAL_CLAIM_APPROVED_DATE_EASTERN
#     - ORIGINAL_CLAIM_APPROVED_DATE_UTC
#     - ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN
#     - ORIGINAL_CLAIM_SUBMITTED_DATE_UTC
#     - ADDPAY_APPROVED_DATE_EASTERN
#     - ADDPAY_APPROVED_DATE_UTC
#     - ADDPAY_SUBMITTED_DATE_EASTERN
#     - ADDPAY_SUBMITTED_DATE_UTC

# %%
rule_df.isnull().sum()
# Out:
# CASE_ID                                        0
# TASK_ID                                        0
# VENDOR_ID                                      0
# CLAIM_ID                                       0
# VENDOR_ADDRESS_ID                           5435
# CLAIM_PO_NUMBER_ENTERED                     2646
# ORIGINAL_CLAIM_PAYMENT_AMOUNT                  0
# ORIGINAL_CLAIM_STATUS_CODE                     0
# ORIGINAL_CLAIM_TYPE_CODE                       0
# SUBMITTED_CLAIM_AMOUNT                         0
# SUBMITTED_TOW_MILES                        58878
# SUBMITTED_ENROUTE_MILES                    15740
# SUBMITTED_LABOR_HOURS                     167879
# SERVICE_ID                                     0
# WAS_AUDITED                                    0
# ADDCHARGE_AMOUNT                         2157721
# IS_CLAIM_APPROVED                              0
# ORIGINAL_CLAIM_APPROVED_PAYMENT                0
# ADDCHARGE_DETAILS                        2157721
# ADDCHARGE_COUNT                                0
# BASE_TOTAL_FROM_RATES                     932307
# ADDPAY_DETAILS                           2573487
# ADDPAY_COUNT                             2573487
# ADDPAY_PAYMENT_AMOUNT                    2573488
# ADDPAY_APPROVED_PAYMENT                  2573488
# COMPLETE_APPROVED_PAYMENT                      0
# IS_VCC                                         0
# ORIGINAL_CLAIM_APPROVED_DATE_EASTERN       64501
# ORIGINAL_CLAIM_APPROVED_DATE_UTC           64501
# SERVICE_DATE_EASTERN                         211
# SERVICE_DATE_UTC                             211
# ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN       3446
# ORIGINAL_CLAIM_SUBMITTED_DATE_UTC           3446
# ADDPAY_APPROVED_DATE_EASTERN             2578916
# ADDPAY_APPROVED_DATE_UTC                 2578916
# ADDPAY_SUBMITTED_DATE_EASTERN            2573491
# ADDPAY_SUBMITTED_DATE_UTC                2573491
# MODIFIED_DATE_EASTERN                          0
# MODIFIED_DATE_UTC                              0
# dtype: int64

# %%
# calculating weight for columns of how often they should be null
null_percents = (1 -(batch.isnull().sum() / len(batch))[batch.isnull().sum() / len(batch) > 0])
for x, y in null_percents.items():
    print(x, y, sep='\n')
    
not_null_weights = dict(null_percents)

# lowering weights by one thousandth of decimal
for key, weight in not_null_weights.items():
    not_null_weights[key] = round((1- weight), 3)
    
print('---------------------------------------')
print('not null weights:')
for x, y in not_null_weights.items():
    print(x,y)
# Out:
# VENDOR_ADDRESS_ID
# 0.9979712147664209
# CLAIM_PO_NUMBER_ENTERED
# 0.9990122970141582
# SUBMITTED_TOW_MILES
# 0.9780219287980372
# SUBMITTED_ENROUTE_MILES
# 0.9941245483759826
# SUBMITTED_LABOR_HOURS
# 0.9373338663793892
# ADDCHARGE_AMOUNT
# 0.19456255694876678
# ADDCHARGE_DETAILS
# 0.19456255694876678
# BASE_TOTAL_FROM_RATES
# 0.6519869963638645
# ADDPAY_DETAILS
# 0.039364779317813015
# ADDPAY_COUNT
# 0.039364779317813015
# ADDPAY_PAYMENT_AMOUNT
# 0.039364406036261346
# ADDPAY_APPROVED_PAYMENT
# 0.039364406036261346
# ORIGINAL_CLAIM_APPROVED_DATE_EASTERN
# 0.9759229666327354
# ORIGINAL_CLAIM_APPROVED_DATE_UTC
# 0.9759229666327354
# SERVICE_DATE_EASTERN
# 0.9999212375925878
# SERVICE_DATE_UTC
# 0.9999212375925878
# ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN
# 0.998713671772785
# ORIGINAL_CLAIM_SUBMITTED_DATE_UTC
# 0.998713671772785
# ADDPAY_APPROVED_DATE_EASTERN
# 0.03733823377354428
# ADDPAY_APPROVED_DATE_UTC
# 0.03733823377354428
# ADDPAY_SUBMITTED_DATE_EASTERN
# 0.03936328619160612
# ADDPAY_SUBMITTED_DATE_UTC
# 0.03936328619160612
# ---------------------------------------
# not null weights:
# VENDOR_ADDRESS_ID 0.002
# CLAIM_PO_NUMBER_ENTERED 0.001
# SUBMITTED_TOW_MILES 0.022
# SUBMITTED_ENROUTE_MILES 0.006
# SUBMITTED_LABOR_HOURS 0.063
# ADDCHARGE_AMOUNT 0.805
# ADDCHARGE_DETAILS 0.805
# BASE_TOTAL_FROM_RATES 0.348
# ADDPAY_DETAILS 0.961
# ADDPAY_COUNT 0.961
# ADDPAY_PAYMENT_AMOUNT 0.961
# ADDPAY_APPROVED_PAYMENT 0.961
# ORIGINAL_CLAIM_APPROVED_DATE_EASTERN 0.024
# ORIGINAL_CLAIM_APPROVED_DATE_UTC 0.024
# SERVICE_DATE_EASTERN 0.0
# SERVICE_DATE_UTC 0.0
# ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN 0.001
# ORIGINAL_CLAIM_SUBMITTED_DATE_UTC 0.001
# ADDPAY_APPROVED_DATE_EASTERN 0.963
# ADDPAY_APPROVED_DATE_UTC 0.963
# ADDPAY_SUBMITTED_DATE_EASTERN 0.961
# ADDPAY_SUBMITTED_DATE_UTC 0.961

# %%
# updated not_null_weights to take into account addpays over daily batch data
not_null_weights = {'VENDOR_ADDRESS_ID': 0.988,
 'CLAIM_PO_NUMBER_ENTERED': 0.989,
 'SUBMITTED_TOW_MILES': 0.968,
 'SUBMITTED_ENROUTE_MILES': 0.984,
 'SUBMITTED_LABOR_HOURS': 0.927,
 'ADDCHARGE_AMOUNT': 0.185,
 'ADDCHARGE_DETAILS': 0.185,
 'BASE_TOTAL_FROM_RATES': 0.642,
 'ADDPAY_DETAILS': 0.005,
 'ADDPAY_COUNT': 0.005,
 'ADDPAY_PAYMENT_AMOUNT': 0.005,
 'ADDPAY_APPROVED_PAYMENT': 0.005,
 'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN': 0.966,
 'ORIGINAL_CLAIM_APPROVED_DATE_UTC': 0.966,
 'SERVICE_DATE_EASTERN': 0.99,
 'SERVICE_DATE_UTC': 0.99,
 'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN': 0.989,
 'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC': 0.989,
 'ADDPAY_APPROVED_DATE_EASTERN': 0.002,
 'ADDPAY_APPROVED_DATE_UTC': 0.002,
 'ADDPAY_SUBMITTED_DATE_EASTERN': 0.005,
 'ADDPAY_SUBMITTED_DATE_UTC': 0.005}

# %%
# validating columns that should be null with 
for col, weight in not_null_weights.items():
    print(col, batch.expect_column_values_to_not_be_null(col, mostly=weight, include_config=True,
                                                           catch_exceptions=True,
                                                           result_format='SUMMARY'), sep='\n')
# Out:
# VENDOR_ADDRESS_ID
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 5435, 'unexpected_percent': 0.20287852335790646, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'VENDOR_ADDRESS_ID', 'mostly': 0.988, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# CLAIM_PO_NUMBER_ENTERED
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2646, 'unexpected_percent': 0.0987702985841804, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'CLAIM_PO_NUMBER_ENTERED', 'mostly': 0.989, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SUBMITTED_TOW_MILES
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 58878, 'unexpected_percent': 2.1978071201962863, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'SUBMITTED_TOW_MILES', 'mostly': 0.968, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SUBMITTED_ENROUTE_MILES
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 15740, 'unexpected_percent': 0.5875451624017383, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'SUBMITTED_ENROUTE_MILES', 'mostly': 0.984, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SUBMITTED_LABOR_HOURS
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 167879, 'unexpected_percent': 6.266613362061081, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'SUBMITTED_LABOR_HOURS', 'mostly': 0.927, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDCHARGE_AMOUNT
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2157721, 'unexpected_percent': 80.54374430512333, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDCHARGE_AMOUNT', 'mostly': 0.185, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDCHARGE_DETAILS
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2157721, 'unexpected_percent': 80.54374430512333, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDCHARGE_DETAILS', 'mostly': 0.185, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# BASE_TOTAL_FROM_RATES
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 932307, 'unexpected_percent': 34.80130036361356, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'BASE_TOTAL_FROM_RATES', 'mostly': 0.642, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_DETAILS
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2573487, 'unexpected_percent': 96.0635220682187, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDPAY_DETAILS', 'mostly': 0.005, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_COUNT
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2573487, 'unexpected_percent': 96.0635220682187, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDPAY_COUNT', 'mostly': 0.005, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_PAYMENT_AMOUNT
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2573488, 'unexpected_percent': 96.06355939637386, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDPAY_PAYMENT_AMOUNT', 'mostly': 0.005, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_APPROVED_PAYMENT
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2573488, 'unexpected_percent': 96.06355939637386, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDPAY_APPROVED_PAYMENT', 'mostly': 0.005, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_APPROVED_DATE_EASTERN
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 64501, 'unexpected_percent': 2.4077033367264624, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN', 'mostly': 0.966, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_APPROVED_DATE_UTC
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 64501, 'unexpected_percent': 2.4077033367264624, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_DATE_UTC', 'mostly': 0.966, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SERVICE_DATE_EASTERN
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 211, 'unexpected_percent': 0.007876240741217712, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'SERVICE_DATE_EASTERN', 'mostly': 0.99, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# SERVICE_DATE_UTC
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 211, 'unexpected_percent': 0.007876240741217712, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'SERVICE_DATE_UTC', 'mostly': 0.99, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 3446, 'unexpected_percent': 0.12863282272149876, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN', 'mostly': 0.989, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ORIGINAL_CLAIM_SUBMITTED_DATE_UTC
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 3446, 'unexpected_percent': 0.12863282272149876, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC', 'mostly': 0.989, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_APPROVED_DATE_EASTERN
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2578916, 'unexpected_percent': 96.26617662264557, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDPAY_APPROVED_DATE_EASTERN', 'mostly': 0.002, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_APPROVED_DATE_UTC
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2578916, 'unexpected_percent': 96.26617662264557, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDPAY_APPROVED_DATE_UTC', 'mostly': 0.002, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_SUBMITTED_DATE_EASTERN
# {'success': True, 'result': {'element_count': 2678943, 'unexpected_count': 2573491, 'unexpected_percent': 96.0636713808394, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDPAY_SUBMITTED_DATE_EASTERN', 'mostly': 0.005, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_SUBMITTED_DATE_UTC
# {'success': False, 'result': {'element_count': 2678943, 'unexpected_count': 2573491, 'unexpected_percent': 96.0636713808394, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_not_be_null', 'kwargs': {'column': 'ADDPAY_SUBMITTED_DATE_UTC', 'mostly': 0.9606, 'result_format': 'SUMMARY'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}

# %% [markdown]
# ### 5. Expecting column values to be in a set
# - original_claim_status_code
# - original_claim_type_code
# - service_id

# %%
batch.head()
# Out:
#       CASE_ID  TASK_ID VENDOR_ID   CLAIM_ID  VENDOR_ADDRESS_ID  \
# 0  2260715166        1     56865  206510333                1.0
# 1  2260643050        1     56865  206510229                6.0
# 2  2233051739        1     56865  112937786                1.0
# 3  2232812263        1     56865  204367999                1.0
# 4  2289358827        2    127957   89538584                1.0
#
#    CLAIM_PO_NUMBER_ENTERED  ORIGINAL_CLAIM_PAYMENT_AMOUNT  \
# 0              961863749.0                          34.24
# 1              231268953.0                          65.27
# 2              952577978.0                          69.02
# 3              170214814.0                          42.27
# 4                      NaN                        -507.69
#
#   ORIGINAL_CLAIM_STATUS_CODE ORIGINAL_CLAIM_TYPE_CODE  SUBMITTED_CLAIM_AMOUNT  \
# 0                         DP                      VND                   34.24
# 1                         DP                      VND                   65.27
# 2                         DP                      VND                   69.02
# 3                         DP                      VND                   42.27
# 4                         PD                      VND                 -507.69
#
#    ...  SERVICE_DATE_EASTERN    SERVICE_DATE_UTC  \
# 0  ...   2018-12-05 00:00:00 2018-12-05 05:00:00
# 1  ...   2018-12-04 00:00:00 2018-12-04 05:00:00
# 2  ...   2018-02-19 00:00:00 2018-02-19 05:00:00
# 3  ...   2018-02-16 00:00:00 2018-02-16 05:00:00
# 4  ...   2018-12-21 12:00:00 2018-12-21 17:00:00
#
#    ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN ORIGINAL_CLAIM_SUBMITTED_DATE_UTC  \
# 0                    2019-11-22 14:24:25               2019-11-22 19:24:25
# 1                    2019-11-22 14:12:54               2019-11-22 19:12:54
# 2                    2019-10-03 11:51:05               2019-10-03 15:51:05
# 3                    2019-10-02 14:42:16               2019-10-02 18:42:16
# 4                    2019-10-21 17:28:51               2019-10-21 21:28:51
#
#    ADDPAY_APPROVED_DATE_EASTERN  ADDPAY_APPROVED_DATE_UTC  \
# 0                           NaT                       NaT
# 1                           NaT                       NaT
# 2                           NaT                       NaT
# 3                           NaT                       NaT
# 4                           NaT                       NaT
#
#    ADDPAY_SUBMITTED_DATE_EASTERN  ADDPAY_SUBMITTED_DATE_UTC  \
# 0                            NaT                        NaT
# 1                            NaT                        NaT
# 2                            NaT                        NaT
# 3                            NaT                        NaT
# 4                            NaT                        NaT
#
#   MODIFIED_DATE_EASTERN   MODIFIED_DATE_UTC
# 0   2019-11-22 14:24:25 2019-11-22 19:24:25
# 1   2019-11-22 14:12:54 2019-11-22 19:12:54
# 2   2019-10-03 11:51:05 2019-10-03 15:51:05
# 3   2019-10-02 14:42:16 2019-10-02 18:42:16
# 4   2019-10-21 17:48:55 2019-10-21 21:48:55
#
# [5 rows x 39 columns]

# %%
category_cols = ['ORIGINAL_CLAIM_STATUS_CODE', 'ORIGINAL_CLAIM_TYPE_CODE', 'SERVICE_ID']

# %%
for col in category_cols:
    print(list(batch.get_column_value_counts(col, sort='value').keys()), '\n')
# Out:
# ['AP', 'DP', 'FC', 'FP', 'HD', 'IN', 'PA', 'PC', 'PD', 'PJ', 'SP', 'VD']
#
# ['OWN', 'VND']
#
# ['GOA', 'LOCK', 'Lock', 'NA', 'REPO', 'ROAD', 'Road', 'TOW', 'Tow', 'Winch', 'null', 'tow']

# %%
print(batch.get_column_value_counts('VENDOR_ADDRESS_ID', sort='value'))
# Out:
# value
# -1.0           6
#  0.0       46432
#  1.0     2331235
#  2.0      143810
#  3.0       60882
#  4.0       64553
#  5.0       10378
#  6.0        4157
#  7.0        6718
#  8.0        1401
#  9.0         783
#  10.0       1727
#  11.0        781
#  12.0        330
#  13.0         50
#  14.0        121
#  15.0         45
#  17.0         87
#  19.0         12
# Name: count, dtype: int64

# %%
val_set_list = []

for col in category_cols:
    list_sets = list(batch.get_column_value_counts(col, sort='value').keys())
    val_set_list.append(list_sets)

# %%
val_set_list
# Out:
# [['AP', 'DP', 'FC', 'FP', 'HD', 'IN', 'PA', 'PC', 'PD', 'PJ', 'SP', 'VD'],
#  ['OWN', 'VND'],
#  ['GOA',
#   'LOCK',
#   'Lock',
#   'NA',
#   'REPO',
#   'ROAD',
#   'Road',
#   'TOW',
#   'Tow',
#   'Winch',
#   'null',
#   'tow']]

# %%
for col, x in zip(category_cols,val_set_list):
    print(col, '\n', x, '\n')
# Out:
# ORIGINAL_CLAIM_STATUS_CODE
#  ['AP', 'DP', 'FC', 'FP', 'HD', 'IN', 'PA', 'PC', 'PD', 'PJ', 'SP', 'VD']
#
# ORIGINAL_CLAIM_TYPE_CODE
#  ['OWN', 'VND']
#
# SERVICE_ID
#  ['GOA', 'LOCK', 'Lock', 'NA', 'REPO', 'ROAD', 'Road', 'TOW', 'Tow', 'Winch', 'null', 'tow']

# %%
for col, vals in zip(category_cols, val_set_list):
    print(col, '\n', batch.expect_column_values_to_be_in_set(col, vals, result_format='BASIC', 
                                        include_config=True, catch_exceptions=True), '\n')
# Out:
# ORIGINAL_CLAIM_STATUS_CODE
#  {'success': True, 'result': {'element_count': 2678943, 'missing_count': 0, 'missing_percent': 0.0, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'unexpected_percent_nonmissing': 0.0, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_be_in_set', 'kwargs': {'column': 'ORIGINAL_CLAIM_STATUS_CODE', 'value_set': ['AP', 'DP', 'FC', 'FP', 'HD', 'IN', 'PA', 'PC', 'PD', 'PJ', 'SP', 'VD'], 'result_format': 'BASIC'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
#
# ORIGINAL_CLAIM_TYPE_CODE
#  {'success': True, 'result': {'element_count': 2678943, 'missing_count': 0, 'missing_percent': 0.0, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'unexpected_percent_nonmissing': 0.0, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_be_in_set', 'kwargs': {'column': 'ORIGINAL_CLAIM_TYPE_CODE', 'value_set': ['OWN', 'VND'], 'result_format': 'BASIC'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
#
# SERVICE_ID
#  {'success': True, 'result': {'element_count': 2678943, 'missing_count': 0, 'missing_percent': 0.0, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'unexpected_percent_nonmissing': 0.0, 'partial_unexpected_list': []}, 'expectation_config': {'expectation_type': 'expect_column_values_to_be_in_set', 'kwargs': {'column': 'SERVICE_ID', 'value_set': ['GOA', 'LOCK', 'Lock', 'NA', 'REPO', 'ROAD', 'Road', 'TOW', 'Tow', 'Winch', 'null', 'tow'], 'result_format': 'BASIC'}}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}

# %% [markdown]
# ### 6. Determine if columns are json parseable
# - addcharge_details
# - addpay_details

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# expect_column_values_to_be_json_parseable
json_columns = ["ADDCHARGE_DETAILS", "ADDPAY_DETAILS"]
for col in json_columns:
    print(col, batch.expect_column_values_to_be_json_parseable(col, result_format='BASIC', mostly=0.98,
                                                               catch_exceptions=True))
# Out:
# ADDCHARGE_DETAILS {'success': True, 'result': {'element_count': 2674621, 'missing_count': 2152143, 'missing_percent': 80.46534443571632, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'unexpected_percent_nonmissing': 0.0, 'partial_unexpected_list': []}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# ADDPAY_DETAILS {'success': True, 'result': {'element_count': 2674621, 'missing_count': 2573850, 'missing_percent': 96.23232600058101, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'unexpected_percent_nonmissing': 0.0, 'partial_unexpected_list': []}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}

# %% [markdown]
# ### 7. Determine if column match json schema
# - addcharge_details: TODO
# - addpay_details: see below

# %%
addpay_schema = {
  "definitions": {},
  "$schema": "http://json-schema.org/draft-07/schema#",
  "$id": "http://example.com/root.json",
  "type": [
    "array",
    "null"
  ],
  "title": "The Root Schema",
  "items": {
    "$id": "#/items",
    "type": [
      "object",
      "null"
    ],
    "title": "The Items Schema",
    "required": [
      "addpay_approved_date",
      "addpay_approved_payment_amount",
      "addpay_claim_id",
      "addpay_is_approved",
      "addpay_payment_amount",
      "addpay_submitted_date",
      "addpay_task_id",
      "addpay_vendor_id",
      "original_claim_amount_paid",
      "original_claim_amount_requested",
      "original_claim_id",
      "original_claim_vendor_id",
      "service_date"
    ],
    "properties": {
      "addpay_approved_date": {
        "$id": "#/items/properties/addpay_approved_date",
        "type": [
          "string",
          "null"
        ],
          "format": "date-time",
        "title": "The Addpay_approved_date Schema",
        "default": "",
        "examples": [
          "2019-02-20T04:02:00"
        ],
        "pattern": "^(.*)$"
      },
      "addpay_approved_payment_amount": {
        "$id": "#/items/properties/addpay_approved_payment_amount",
        "type": [
          "number",
          "null"
        ],
        "title": "The Addpay_approved_payment_amount Schema",
        "default": 0,
        "examples": [
          27
        ]
      },
      "addpay_claim_id": {
        "$id": "#/items/properties/addpay_claim_id",
        "type": [
          "number",
          "null"
        ],
        "title": "The Addpay_claim_id Schema",
        "default": 0,
        "examples": [
          88551584
        ]
      },
      "addpay_is_approved": {
        "$id": "#/items/properties/addpay_is_approved",
        "type": [
          "boolean",
          "null"
        ],
        "title": "The Addpay_is_approved Schema",
        "default": False,
        "examples": [
          True
        ]
      },
      "addpay_payment_amount": {
        "$id": "#/items/properties/addpay_payment_amount",
        "type": [
          "number",
          "null"
        ],
        "title": "The Addpay_payment_amount Schema",
        "default": 0,
        "examples": [
          27
        ]
      },
      "addpay_submitted_date": {
        "$id": "#/items/properties/addpay_submitted_date",
        "type": [
          "string",
          "null"
        ],
          "format": "date-time",
        "title": "The Addpay_submitted_date Schema",
        "default": "",
        "examples": [
          "2019-02-19T00:00:00"
        ],
        "pattern": "^(.*)$"
      },
      "addpay_task_id": {
        "$id": "#/items/properties/addpay_task_id",
        "type": [
          "number",
          "null"
        ],
        "title": "The Addpay_task_id Schema",
        "default": 0,
        "examples": [
          2
        ]
      },
      "addpay_vendor_id": {
        "$id": "#/items/properties/addpay_vendor_id",
        "type": [
          "string",
          "null"
        ],
        "title": "The Addpay_vendor_id Schema",
        "default": "",
        "examples": [
          "133573"
        ],
        "pattern": "^(.*)$"
      },
      "original_claim_amount_paid": {
        "$id": "#/items/properties/original_claim_amount_paid",
        "type": [
          "number",
          "null"
        ],
        "title": "The Original_claim_amount_paid Schema",
        "default": 0.0,
        "examples": [
          57.95
        ]
      },
      "original_claim_amount_requested": {
        "$id": "#/items/properties/original_claim_amount_requested",
        "type": [
          "number",
          "null"
        ],
        "title": "The Original_claim_amount_requested Schema",
        "default": 0,
        "examples": [
          59
        ]
      },
      "original_claim_id": {
        "$id": "#/items/properties/original_claim_id",
        "type": [
          "number",
          "null"
        ],
        "title": "The Original_claim_id Schema",
        "default": 0,
        "examples": [
          195082625
        ]
      },
      "original_claim_vendor_id": {
        "$id": "#/items/properties/original_claim_vendor_id",
        "type": [
          "string",
          "null"
        ],
        "title": "The Original_claim_vendor_id Schema",
        "default": "",
        "examples": [
          "133573"
        ],
        "pattern": "^(.*)$"
      },
      "service_date": {
        "$id": "#/items/properties/service_date",
        "type": [
          "string",
          "null"
        ],
          "format": "date-time",
        "title": "The Service_date Schema",
        "default": "",
        "examples": [
          "2019-02-14T11:50:21"
        ],
        "pattern": "^(.*)$"
      }
    }
  }
}

# %%
# expect_column_values_to_match_json_schema
batch.expect_column_values_to_match_json_schema('ADDPAY_DETAILS', addpay_schema, mostly=0.92, 
                                               result_format='BASIC')
# Out:
# {'success': True,
#  'result': {'element_count': 2674621,
#   'missing_count': 2573850,
#   'missing_percent': 96.23232600058101,
#   'unexpected_count': 2647,
#   'unexpected_percent': 0.09896729293608329,
#   'unexpected_percent_nonmissing': 2.6267477746573915,
#   'partial_unexpected_list': ['[\n  {\n    "addpay_approved_date": "2019-11-02T04:03:05",\n    "addpay_approved_payment_amount": 21,\n    "addpay_claim_id": 89581222,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 21,\n    "addpay_submitted_date": "2019-11-01T00:00:00",\n    "addpay_vendor_id": "300733",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-10T14:48:38"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-24T12:22:04",\n    "addpay_approved_payment_amount": 100,\n    "addpay_claim_id": 89549080,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 100,\n    "addpay_submitted_date": "2019-10-24T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-14T05:03:48"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-25T11:06:59",\n    "addpay_approved_payment_amount": 149,\n    "addpay_claim_id": 89554114,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 149,\n    "addpay_submitted_date": "2019-10-25T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-13T14:18:14"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-25T11:06:59",\n    "addpay_approved_payment_amount": 152.25,\n    "addpay_claim_id": 89554134,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 152.25,\n    "addpay_submitted_date": "2019-10-25T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-15T12:12:30"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-28T10:30:04",\n    "addpay_approved_payment_amount": 358.68,\n    "addpay_claim_id": 89561366,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 358.68,\n    "addpay_submitted_date": "2019-10-28T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-19T06:07:24"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-29T10:08:08",\n    "addpay_approved_payment_amount": 12.4,\n    "addpay_claim_id": 118185699,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 12.4,\n    "addpay_submitted_date": "2019-10-28T00:06:16",\n    "addpay_vendor_id": "19569",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-11T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-17T10:14:35",\n    "addpay_approved_payment_amount": 400,\n    "addpay_claim_id": 89521902,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 400,\n    "addpay_submitted_date": "2019-10-16T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-15T10:01:17"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-18T07:58:42",\n    "addpay_approved_payment_amount": 50,\n    "addpay_claim_id": 89526996,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 50,\n    "addpay_submitted_date": "2019-10-18T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-08T20:24:40"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "NaT",\n    "addpay_approved_payment_amount": 0,\n    "addpay_claim_id": 118266771,\n    "addpay_is_approved": false,\n    "addpay_payment_amount": 60,\n    "addpay_submitted_date": "2019-12-07T00:04:55",\n    "addpay_vendor_id": "122419",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-09T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-01T15:26:25",\n    "addpay_approved_payment_amount": 48.5,\n    "addpay_claim_id": 89575524,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 48.5,\n    "addpay_submitted_date": "2019-10-31T00:11:28",\n    "addpay_vendor_id": "134131",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-11T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-28T10:30:04",\n    "addpay_approved_payment_amount": 193.88,\n    "addpay_claim_id": 89555060,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 193.88,\n    "addpay_submitted_date": "2019-10-25T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-15T12:12:30"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-12-11T16:46:39",\n    "addpay_approved_payment_amount": 152,\n    "addpay_claim_id": 89746624,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 152,\n    "addpay_submitted_date": "2019-12-11T00:00:00",\n    "addpay_vendor_id": "100844",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-19T16:11:35"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-04T15:56:24",\n    "addpay_approved_payment_amount": 187,\n    "addpay_claim_id": 89582878,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 187,\n    "addpay_submitted_date": "2019-11-01T12:11:32",\n    "addpay_vendor_id": "66435",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-09T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-21T14:50:50",\n    "addpay_approved_payment_amount": 301,\n    "addpay_claim_id": 118171875,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 301,\n    "addpay_submitted_date": "2019-10-21T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-12T01:03:10"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-15T09:16:17",\n    "addpay_approved_payment_amount": 422.3,\n    "addpay_claim_id": 118159097,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 422.3,\n    "addpay_submitted_date": "2019-10-13T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-04T19:03:30"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-14T08:29:02",\n    "addpay_approved_payment_amount": 89.95,\n    "addpay_claim_id": 89507242,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 89.95,\n    "addpay_submitted_date": "2019-10-14T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-03T13:54:39"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-15T15:53:07",\n    "addpay_approved_payment_amount": 44.35,\n    "addpay_claim_id": 118160397,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 44.35,\n    "addpay_submitted_date": "2019-10-15T12:01:23",\n    "addpay_vendor_id": "130018",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-06T05:46:57"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-11T09:45:35",\n    "addpay_approved_payment_amount": 350,\n    "addpay_claim_id": 89499018,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 350,\n    "addpay_submitted_date": "2019-10-11T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T15:15:15"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-17T10:34:59",\n    "addpay_approved_payment_amount": 120,\n    "addpay_claim_id": 118161745,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 120,\n    "addpay_submitted_date": "2019-10-16T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T12:08:05"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-11T09:49:16",\n    "addpay_approved_payment_amount": 450,\n    "addpay_claim_id": 89499456,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 450,\n    "addpay_submitted_date": "2019-10-11T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T18:36:52"\n  }\n]'],
#   'partial_unexpected_index_list': [510,
#    1316,
#    1428,
#    4686,
#    4781,
#    5187,
#    6032,
#    7234,
#    9864,
#    11710,
#    11954,
#    13714,
#    14755,
#    16974,
#    22352,
#    22715,
#    23891,
#    25324,
#    25617,
#    26959],
#   'partial_unexpected_counts': [{'value': '[\n  {\n    "addpay_approved_date": "2019-10-11T09:45:35",\n    "addpay_approved_payment_amount": 350,\n    "addpay_claim_id": 89499018,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 350,\n    "addpay_submitted_date": "2019-10-11T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T15:15:15"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-11T09:49:16",\n    "addpay_approved_payment_amount": 450,\n    "addpay_claim_id": 89499456,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 450,\n    "addpay_submitted_date": "2019-10-11T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T18:36:52"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-14T08:29:02",\n    "addpay_approved_payment_amount": 89.95,\n    "addpay_claim_id": 89507242,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 89.95,\n    "addpay_submitted_date": "2019-10-14T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-03T13:54:39"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-15T09:16:17",\n    "addpay_approved_payment_amount": 422.3,\n    "addpay_claim_id": 118159097,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 422.3,\n    "addpay_submitted_date": "2019-10-13T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-04T19:03:30"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-15T15:53:07",\n    "addpay_approved_payment_amount": 44.35,\n    "addpay_claim_id": 118160397,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 44.35,\n    "addpay_submitted_date": "2019-10-15T12:01:23",\n    "addpay_vendor_id": "130018",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-06T05:46:57"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-17T10:14:35",\n    "addpay_approved_payment_amount": 400,\n    "addpay_claim_id": 89521902,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 400,\n    "addpay_submitted_date": "2019-10-16T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-15T10:01:17"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-17T10:34:59",\n    "addpay_approved_payment_amount": 120,\n    "addpay_claim_id": 118161745,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 120,\n    "addpay_submitted_date": "2019-10-16T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T12:08:05"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-18T07:58:42",\n    "addpay_approved_payment_amount": 50,\n    "addpay_claim_id": 89526996,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 50,\n    "addpay_submitted_date": "2019-10-18T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-08T20:24:40"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-21T14:50:50",\n    "addpay_approved_payment_amount": 301,\n    "addpay_claim_id": 118171875,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 301,\n    "addpay_submitted_date": "2019-10-21T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-12T01:03:10"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-24T12:22:04",\n    "addpay_approved_payment_amount": 100,\n    "addpay_claim_id": 89549080,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 100,\n    "addpay_submitted_date": "2019-10-24T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-14T05:03:48"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-25T11:06:59",\n    "addpay_approved_payment_amount": 149,\n    "addpay_claim_id": 89554114,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 149,\n    "addpay_submitted_date": "2019-10-25T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-13T14:18:14"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-25T11:06:59",\n    "addpay_approved_payment_amount": 152.25,\n    "addpay_claim_id": 89554134,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 152.25,\n    "addpay_submitted_date": "2019-10-25T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-15T12:12:30"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-28T10:30:04",\n    "addpay_approved_payment_amount": 193.88,\n    "addpay_claim_id": 89555060,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 193.88,\n    "addpay_submitted_date": "2019-10-25T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-15T12:12:30"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-28T10:30:04",\n    "addpay_approved_payment_amount": 358.68,\n    "addpay_claim_id": 89561366,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 358.68,\n    "addpay_submitted_date": "2019-10-28T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-19T06:07:24"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-10-29T10:08:08",\n    "addpay_approved_payment_amount": 12.4,\n    "addpay_claim_id": 118185699,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 12.4,\n    "addpay_submitted_date": "2019-10-28T00:06:16",\n    "addpay_vendor_id": "19569",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-11T12:00:00"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-11-01T15:26:25",\n    "addpay_approved_payment_amount": 48.5,\n    "addpay_claim_id": 89575524,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 48.5,\n    "addpay_submitted_date": "2019-10-31T00:11:28",\n    "addpay_vendor_id": "134131",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-11T12:00:00"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-11-02T04:03:05",\n    "addpay_approved_payment_amount": 21,\n    "addpay_claim_id": 89581222,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 21,\n    "addpay_submitted_date": "2019-11-01T00:00:00",\n    "addpay_vendor_id": "300733",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-10T14:48:38"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-11-04T15:56:24",\n    "addpay_approved_payment_amount": 187,\n    "addpay_claim_id": 89582878,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 187,\n    "addpay_submitted_date": "2019-11-01T12:11:32",\n    "addpay_vendor_id": "66435",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-09T12:00:00"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "2019-12-11T16:46:39",\n    "addpay_approved_payment_amount": 152,\n    "addpay_claim_id": 89746624,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 152,\n    "addpay_submitted_date": "2019-12-11T00:00:00",\n    "addpay_vendor_id": "100844",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-19T16:11:35"\n  }\n]',
#     'count': 1},
#    {'value': '[\n  {\n    "addpay_approved_date": "NaT",\n    "addpay_approved_payment_amount": 0,\n    "addpay_claim_id": 118266771,\n    "addpay_is_approved": false,\n    "addpay_payment_amount": 60,\n    "addpay_submitted_date": "2019-12-07T00:04:55",\n    "addpay_vendor_id": "122419",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-09T12:00:00"\n  }\n]',
#     'count': 1}],
#   'unexpected_list': ['[\n  {\n    "addpay_approved_date": "2019-11-02T04:03:05",\n    "addpay_approved_payment_amount": 21,\n    "addpay_claim_id": 89581222,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 21,\n    "addpay_submitted_date": "2019-11-01T00:00:00",\n    "addpay_vendor_id": "300733",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-10T14:48:38"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-24T12:22:04",\n    "addpay_approved_payment_amount": 100,\n    "addpay_claim_id": 89549080,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 100,\n    "addpay_submitted_date": "2019-10-24T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-14T05:03:48"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-25T11:06:59",\n    "addpay_approved_payment_amount": 149,\n    "addpay_claim_id": 89554114,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 149,\n    "addpay_submitted_date": "2019-10-25T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-13T14:18:14"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-25T11:06:59",\n    "addpay_approved_payment_amount": 152.25,\n    "addpay_claim_id": 89554134,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 152.25,\n    "addpay_submitted_date": "2019-10-25T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-15T12:12:30"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-28T10:30:04",\n    "addpay_approved_payment_amount": 358.68,\n    "addpay_claim_id": 89561366,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 358.68,\n    "addpay_submitted_date": "2019-10-28T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-19T06:07:24"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-29T10:08:08",\n    "addpay_approved_payment_amount": 12.4,\n    "addpay_claim_id": 118185699,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 12.4,\n    "addpay_submitted_date": "2019-10-28T00:06:16",\n    "addpay_vendor_id": "19569",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-11T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-17T10:14:35",\n    "addpay_approved_payment_amount": 400,\n    "addpay_claim_id": 89521902,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 400,\n    "addpay_submitted_date": "2019-10-16T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-15T10:01:17"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-18T07:58:42",\n    "addpay_approved_payment_amount": 50,\n    "addpay_claim_id": 89526996,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 50,\n    "addpay_submitted_date": "2019-10-18T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-08T20:24:40"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "NaT",\n    "addpay_approved_payment_amount": 0,\n    "addpay_claim_id": 118266771,\n    "addpay_is_approved": false,\n    "addpay_payment_amount": 60,\n    "addpay_submitted_date": "2019-12-07T00:04:55",\n    "addpay_vendor_id": "122419",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-09T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-01T15:26:25",\n    "addpay_approved_payment_amount": 48.5,\n    "addpay_claim_id": 89575524,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 48.5,\n    "addpay_submitted_date": "2019-10-31T00:11:28",\n    "addpay_vendor_id": "134131",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-11T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-28T10:30:04",\n    "addpay_approved_payment_amount": 193.88,\n    "addpay_claim_id": 89555060,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 193.88,\n    "addpay_submitted_date": "2019-10-25T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-15T12:12:30"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-12-11T16:46:39",\n    "addpay_approved_payment_amount": 152,\n    "addpay_claim_id": 89746624,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 152,\n    "addpay_submitted_date": "2019-12-11T00:00:00",\n    "addpay_vendor_id": "100844",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-19T16:11:35"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-04T15:56:24",\n    "addpay_approved_payment_amount": 187,\n    "addpay_claim_id": 89582878,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 187,\n    "addpay_submitted_date": "2019-11-01T12:11:32",\n    "addpay_vendor_id": "66435",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-09T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-21T14:50:50",\n    "addpay_approved_payment_amount": 301,\n    "addpay_claim_id": 118171875,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 301,\n    "addpay_submitted_date": "2019-10-21T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-12T01:03:10"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-15T09:16:17",\n    "addpay_approved_payment_amount": 422.3,\n    "addpay_claim_id": 118159097,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 422.3,\n    "addpay_submitted_date": "2019-10-13T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-04T19:03:30"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-14T08:29:02",\n    "addpay_approved_payment_amount": 89.95,\n    "addpay_claim_id": 89507242,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 89.95,\n    "addpay_submitted_date": "2019-10-14T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-03T13:54:39"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-15T15:53:07",\n    "addpay_approved_payment_amount": 44.35,\n    "addpay_claim_id": 118160397,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 44.35,\n    "addpay_submitted_date": "2019-10-15T12:01:23",\n    "addpay_vendor_id": "130018",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-06T05:46:57"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-11T09:45:35",\n    "addpay_approved_payment_amount": 350,\n    "addpay_claim_id": 89499018,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 350,\n    "addpay_submitted_date": "2019-10-11T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T15:15:15"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-17T10:34:59",\n    "addpay_approved_payment_amount": 120,\n    "addpay_claim_id": 118161745,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 120,\n    "addpay_submitted_date": "2019-10-16T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T12:08:05"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-11T09:49:16",\n    "addpay_approved_payment_amount": 450,\n    "addpay_claim_id": 89499456,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 450,\n    "addpay_submitted_date": "2019-10-11T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T18:36:52"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-11T09:45:35",\n    "addpay_approved_payment_amount": 672.05,\n    "addpay_claim_id": 89498986,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 672.05,\n    "addpay_submitted_date": "2019-10-10T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T16:00:25"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-29T13:31:23",\n    "addpay_approved_payment_amount": 15,\n    "addpay_claim_id": 118180567,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 15,\n    "addpay_submitted_date": "2019-10-18T00:00:00",\n    "addpay_vendor_id": "30913",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-02T07:42:58"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-09T13:10:42",\n    "addpay_approved_payment_amount": 65.71,\n    "addpay_claim_id": 118150467,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 65.71,\n    "addpay_submitted_date": "2019-10-09T00:00:00",\n    "addpay_vendor_id": "30905",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-01T13:29:12"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-18T12:43:40",\n    "addpay_approved_payment_amount": 35,\n    "addpay_claim_id": 89527414,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 35,\n    "addpay_submitted_date": "2019-10-18T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-05T16:31:47"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "NaT",\n    "addpay_approved_payment_amount": 0,\n    "addpay_claim_id": 118413685,\n    "addpay_is_approved": false,\n    "addpay_payment_amount": 12.25,\n    "addpay_submitted_date": "2020-02-19T12:04:33",\n    "addpay_vendor_id": "131557",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-02T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-04T07:29:53",\n    "addpay_approved_payment_amount": 90,\n    "addpay_claim_id": 89589912,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 90,\n    "addpay_submitted_date": "2019-11-04T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-28T10:01:17"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-05T11:20:52",\n    "addpay_approved_payment_amount": 45,\n    "addpay_claim_id": 89595910,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 45,\n    "addpay_submitted_date": "2019-11-05T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-30T12:32:15"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-08T10:17:48",\n    "addpay_approved_payment_amount": 433.65,\n    "addpay_claim_id": 89611060,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 433.65,\n    "addpay_submitted_date": "2019-11-08T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-02T12:46:29"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-09T05:39:46",\n    "addpay_approved_payment_amount": 90,\n    "addpay_claim_id": 89615282,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 90,\n    "addpay_submitted_date": "2019-11-09T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-03T12:21:15"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-20T04:02:35",\n    "addpay_approved_payment_amount": 25,\n    "addpay_claim_id": 89653920,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 25,\n    "addpay_submitted_date": "2019-11-06T00:00:00",\n    "addpay_vendor_id": "98926",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-04T19:14:26"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-23T04:02:25",\n    "addpay_approved_payment_amount": 21.78,\n    "addpay_claim_id": 89671916,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 21.78,\n    "addpay_submitted_date": "2019-11-22T00:00:00",\n    "addpay_vendor_id": "311487",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-13T13:16:54"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-20T04:02:35",\n    "addpay_approved_payment_amount": 25,\n    "addpay_claim_id": 89653946,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 25,\n    "addpay_submitted_date": "2019-11-06T00:00:00",\n    "addpay_vendor_id": "98926",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-12T03:25:11"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-01T11:30:59",\n    "addpay_approved_payment_amount": 150,\n    "addpay_claim_id": 89576554,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 150,\n    "addpay_submitted_date": "2019-10-31T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-22T15:10:25"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-04T11:34:51",\n    "addpay_approved_payment_amount": 123,\n    "addpay_claim_id": 89587820,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 123,\n    "addpay_submitted_date": "2019-11-02T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-24T23:23:48"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-07T13:39:22",\n    "addpay_approved_payment_amount": 375,\n    "addpay_claim_id": 118202277,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 375,\n    "addpay_submitted_date": "2019-11-06T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-24T02:21:24"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-08T10:17:48",\n    "addpay_approved_payment_amount": 195,\n    "addpay_claim_id": 89610572,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 195,\n    "addpay_submitted_date": "2019-11-08T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-31T19:48:27"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-05T04:02:54",\n    "addpay_approved_payment_amount": 45,\n    "addpay_claim_id": 89593094,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 45,\n    "addpay_submitted_date": "2019-11-04T00:00:00",\n    "addpay_vendor_id": "120835",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-28T08:30:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-05T04:02:54",\n    "addpay_approved_payment_amount": 51,\n    "addpay_claim_id": 89593104,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 51,\n    "addpay_submitted_date": "2019-11-04T00:00:00",\n    "addpay_vendor_id": "120835",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-30T13:15:18"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-31T09:24:07",\n    "addpay_approved_payment_amount": 125,\n    "addpay_claim_id": 89574294,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 125,\n    "addpay_submitted_date": "2019-10-30T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-22T10:06:51"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-10T00:22:41",\n    "addpay_approved_payment_amount": 475,\n    "addpay_claim_id": 89615344,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 475,\n    "addpay_submitted_date": "2019-11-09T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-02T10:53:21"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-11-05T13:38:21",\n    "addpay_approved_payment_amount": 350,\n    "addpay_claim_id": 89595748,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 350,\n    "addpay_submitted_date": "2019-11-05T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-29T09:50:30"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-12-06T11:52:28",\n    "addpay_approved_payment_amount": 60,\n    "addpay_claim_id": 89724238,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 60,\n    "addpay_submitted_date": "2019-12-06T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-12-01T11:17:05"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2020-01-10T04:00:07",\n    "addpay_approved_payment_amount": 23,\n    "addpay_claim_id": 89863248,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 23,\n    "addpay_submitted_date": "2020-01-09T00:00:00",\n    "addpay_vendor_id": "116035",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-06T13:03:48"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-12-31T09:29:39",\n    "addpay_approved_payment_amount": 20,\n    "addpay_claim_id": 118308841,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 20,\n    "addpay_submitted_date": "2019-12-28T00:27:33",\n    "addpay_vendor_id": "33887",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-07T12:00:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2020-01-10T16:22:28",\n    "addpay_approved_payment_amount": 51.48,\n    "addpay_claim_id": 89866954,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 51.48,\n    "addpay_submitted_date": "2020-01-09T00:00:00",\n    "addpay_vendor_id": "96013",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-11T05:55:24"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2020-01-02T08:32:24",\n    "addpay_approved_payment_amount": 22.75,\n    "addpay_claim_id": 118311689,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 22.75,\n    "addpay_submitted_date": "2019-12-29T12:01:02",\n    "addpay_vendor_id": "42244",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-16T12:00:00"\n  }\n]',
# ...
#    '[\n  {\n    "addpay_approved_date": "2019-12-17T04:01:24",\n    "addpay_approved_payment_amount": 31,\n    "addpay_claim_id": 89766764,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 31,\n    "addpay_submitted_date": "2019-12-16T00:00:00",\n    "addpay_vendor_id": "102450",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-27T14:03:50"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-12-24T04:00:27",\n    "addpay_approved_payment_amount": 34,\n    "addpay_claim_id": 89795568,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 34,\n    "addpay_submitted_date": "2019-12-23T00:00:00",\n    "addpay_vendor_id": "102231",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-17T10:02:14"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-28T10:30:04",\n    "addpay_approved_payment_amount": 120,\n    "addpay_claim_id": 89558000,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 120,\n    "addpay_submitted_date": "2019-10-26T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-08T11:40:40"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2019-10-28T10:30:04",\n    "addpay_approved_payment_amount": 210,\n    "addpay_claim_id": 89558044,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 210,\n    "addpay_submitted_date": "2019-10-26T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-18T12:54:12"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2020-01-22T10:10:14",\n    "addpay_approved_payment_amount": 38,\n    "addpay_claim_id": 89912926,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 38,\n    "addpay_submitted_date": "2020-01-22T00:00:00",\n    "addpay_vendor_id": "109202",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-28T12:04:45"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2020-01-13T11:09:03",\n    "addpay_approved_payment_amount": 55,\n    "addpay_claim_id": 89846852,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 55,\n    "addpay_submitted_date": "2019-12-27T00:00:00",\n    "addpay_vendor_id": "03548",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-07T14:52:35"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2020-01-16T15:35:16",\n    "addpay_approved_payment_amount": 54,\n    "addpay_claim_id": 89881356,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 54,\n    "addpay_submitted_date": "2020-01-15T00:01:36",\n    "addpay_vendor_id": "114571",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-11-17T02:46:34"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2020-01-17T04:00:48",\n    "addpay_approved_payment_amount": 93.2,\n    "addpay_claim_id": 89892578,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 93.2,\n    "addpay_submitted_date": "2020-01-13T00:00:00",\n    "addpay_vendor_id": "04992",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-30T09:08:00"\n  }\n]',
#    '[\n  {\n    "addpay_approved_date": "2020-01-15T10:13:34",\n    "addpay_approved_payment_amount": 860.59,\n    "addpay_claim_id": 118343207,\n    "addpay_is_approved": true,\n    "addpay_payment_amount": 860.59,\n    "addpay_submitted_date": "2020-01-14T00:00:00",\n    "addpay_vendor_id": "20921",\n    "original_claim_amount_paid": null,\n    "original_claim_amount_requested": null,\n    "original_claim_id": null,\n    "original_claim_task_id": null,\n    "original_claim_vendor_id": null,\n    "service_date": "2019-10-27T22:38:03"\n  }\n]',
#    ...],
#   'unexpected_index_list': [510,
#    1316,
#    1428,
#    4686,
#    4781,
#    5187,
#    6032,
#    7234,
#    9864,
#    11710,
#    11954,
#    13714,
#    14755,
#    16974,
#    22352,
#    22715,
#    23891,
#    25324,
#    25617,
#    26959,
#    27008,
#    28406,
#    29061,
#    30206,
#    31325,
#    33957,
#    34208,
#    34503,
#    34706,
#    35102,
#    35335,
#    35478,
#    36154,
#    38153,
#    38295,
#    38774,
#    42170,
#    42520,
#    43297,
#    46011,
#    46054,
#    47892,
#    48637,
#    48687,
#    48802,
#    48871,
#    48936,
#    48969,
#    52915,
#    55139,
#    55363,
#    55582,
#    55935,
#    57766,
#    59167,
#    59186,
#    59275,
#    59715,
#    63081,
#    66499,
#    66833,
#    67363,
#    67373,
#    67430,
#    67503,
#    68393,
#    71056,
#    73215,
#    73985,
#    76067,
#    77054,
#    81684,
#    81685,
#    83955,
#    85370,
#    88589,
#    88602,
#    88857,
#    90002,
#    90996,
#    91298,
#    94016,
#    94091,
#    95346,
#    96053,
#    97059,
#    97180,
#    97284,
#    98618,
#    98840,
#    99413,
#    100839,
#    100941,
#    101768,
#    102875,
#    106025,
#    106938,
#    109684,
#    110087,
#    113477,
#    113923,
#    114009,
#    114401,
#    116077,
#    117107,
#    117109,
#    117452,
#    121562,
#    122312,
#    123373,
#    124784,
#    125330,
#    128483,
#    129095,
#    129330,
#    132452,
#    133589,
#    134661,
#    134917,
#    136227,
#    136939,
#    139533,
#    139826,
#    139883,
#    143183,
#    144536,
#    145774,
#    146029,
#    148318,
#    149709,
#    151381,
#    151960,
#    153667,
#    154116,
#    155482,
#    157823,
#    158086,
#    158297,
#    159827,
#    160878,
#    162049,
#    164700,
#    166463,
#    166754,
#    171374,
#    171580,
#    172405,
#    173485,
#    173955,
#    174374,
#    174423,
#    174724,
#    177370,
#    177852,
#    178996,
#    179905,
#    181841,
#    182811,
#    182832,
#    183359,
#    183660,
#    183863,
#    184127,
#    184233,
#    186439,
#    188575,
#    190651,
#    193635,
#    197174,
#    197811,
#    198137,
#    198684,
#    201339,
#    201710,
#    201972,
#    202605,
#    202789,
#    203573,
#    206328,
#    208304,
#    209269,
#    212644,
#    212734,
#    213156,
#    215173,
#    215276,
#    216166,
#    217566,
#    219676,
#    219751,
#    219845,
#    221457,
#    222232,
#    222257,
#    223340,
#    223586,
#    225732,
#    225955,
#    230580,
#    231447,
#    232259,
#    233751,
#    233804,
#    234713,
#    234912,
#    235460,
#    235497,
#    235539,
#    237736,
#    240467,
#    241287,
#    242493,
#    244001,
#    244251,
#    245097,
#    245588,
#    248283,
#    251124,
#    251545,
#    253739,
#    254609,
#    255468,
#    255911,
#    256619,
#    257669,
#    258637,
#    258835,
#    259022,
#    261128,
#    262943,
#    264719,
#    264900,
#    265521,
#    265743,
#    266671,
#    267060,
#    269293,
#    270141,
#    272146,
#    272461,
#    272666,
#    272694,
#    273483,
#    273732,
#    273747,
#    274009,
#    276759,
#    277474,
#    280626,
#    281170,
#    281770,
#    283474,
#    284339,
#    286055,
#    288255,
#    289718,
#    290097,
#    290590,
#    291251,
#    291358,
#    295319,
#    296187,
#    298318,
#    298434,
#    298843,
#    299102,
#    299489,
#    300168,
#    303727,
#    303821,
#    304120,
#    304552,
#    309483,
#    313714,
#    313813,
#    315289,
#    315449,
#    316177,
#    316348,
#    316913,
#    317154,
#    318722,
#    319237,
#    322451,
#    324344,
#    325183,
#    326219,
#    327307,
#    328172,
#    329850,
#    330274,
#    331557,
#    331855,
#    338249,
#    339415,
#    342158,
#    343674,
#    343798,
#    345431,
#    346898,
#    347374,
#    347612,
#    347772,
#    348849,
#    349668,
#    352844,
#    353006,
#    354156,
#    354228,
#    355301,
#    356228,
#    356494,
#    357215,
#    357410,
#    357612,
#    358842,
#    359958,
#    362093,
#    362936,
#    363731,
#    369563,
#    370226,
#    370801,
#    372565,
#    376100,
#    377050,
#    377172,
#    377763,
#    378166,
#    379563,
#    381799,
#    381812,
#    382419,
#    382908,
#    383130,
#    383590,
#    385592,
#    386289,
#    390252,
#    392866,
#    392931,
#    393009,
#    393010,
#    393107,
#    393324,
#    394427,
#    395668,
#    397823,
#    398178,
#    398664,
#    400904,
#    401292,
#    401455,
#    402778,
#    402931,
#    403561,
#    407072,
#    409323,
#    409833,
#    415458,
#    415897,
#    417353,
#    418420,
#    418474,
#    420822,
#    421080,
#    421796,
#    422093,
#    422464,
#    424803,
#    425593,
#    426054,
#    426651,
#    426772,
#    427851,
#    427990,
#    428058,
#    429232,
#    430306,
#    432213,
#    432609,
#    433771,
#    434134,
#    436790,
#    437406,
#    439283,
#    441616,
#    442194,
#    445469,
#    445510,
#    445671,
#    448602,
#    448726,
#    449396,
#    452212,
#    452310,
#    453047,
#    455753,
#    456184,
#    457114,
#    457984,
#    458468,
#    458596,
#    458621,
#    458768,
#    460366,
#    461220,
#    461643,
#    461650,
#    461652,
#    461721,
#    461867,
#    463054,
#    464155,
#    466272,
#    467727,
#    467747,
#    469202,
#    469720,
#    469811,
#    469817,
#    471191,
#    472245,
#    473792,
#    476970,
#    476977,
#    479176,
#    481616,
#    484473,
#    484662,
#    485865,
#    487516,
#    489263,
#    489742,
#    490740,
#    490910,
#    490967,
#    491060,
#    491157,
#    492565,
#    493033,
#    493295,
#    493551,
#    493896,
#    496283,
#    499514,
#    500540,
#    501019,
#    501340,
#    502385,
#    504689,
#    505169,
#    506772,
#    508103,
#    508442,
#    508574,
#    510359,
#    512547,
#    513823,
#    514607,
#    514879,
#    515369,
#    516630,
#    518288,
#    518795,
#    518864,
#    519065,
#    522711,
#    523108,
#    525224,
#    526544,
#    527625,
#    529713,
#    529796,
#    529923,
#    530051,
#    531235,
#    531461,
#    531725,
#    532497,
#    532834,
#    534153,
#    537016,
#    537215,
#    537391,
#    540730,
#    541506,
#    545203,
#    545616,
#    546686,
#    548118,
#    548710,
#    548901,
#    548913,
#    548976,
#    549187,
#    549351,
#    549487,
#    549688,
#    551571,
#    551736,
#    553687,
#    555346,
#    556788,
#    557672,
#    558977,
#    560554,
#    560632,
#    560645,
#    560691,
#    560776,
#    561634,
#    562019,
#    562219,
#    562616,
#    563238,
#    566641,
#    566699,
#    567057,
#    572738,
#    574042,
#    575009,
#    575231,
#    575240,
#    576105,
#    578936,
#    579938,
#    581746,
#    582415,
#    583309,
#    584485,
#    585276,
#    585460,
#    585782,
#    586186,
#    586388,
#    588519,
#    588687,
#    589341,
#    591414,
#    591982,
#    593736,
#    594188,
#    594205,
#    595559,
#    596971,
#    597199,
#    597977,
#    600347,
#    601370,
#    604126,
#    604812,
#    606848,
#    607042,
#    608019,
#    608187,
#    608367,
#    611053,
#    611543,
#    611857,
#    612437,
#    612557,
#    615419,
#    615628,
#    616161,
#    616196,
#    617059,
#    617215,
#    617277,
#    619524,
#    621906,
#    623759,
#    623839,
#    624085,
#    626056,
#    627717,
#    627888,
#    630390,
#    633348,
#    634246,
#    634392,
#    637935,
#    638078,
#    639969,
#    640986,
#    641271,
#    641554,
#    642247,
#    642614,
#    642755,
#    644993,
#    645920,
#    645927,
#    645968,
#    646029,
#    646126,
#    646170,
#    646235,
#    646556,
#    646957,
#    648619,
#    649777,
#    651291,
#    652047,
#    652876,
#    655947,
#    656350,
#    657192,
#    657766,
#    657880,
#    660940,
#    661226,
#    665423,
#    665669,
#    667064,
#    668096,
#    670830,
#    671396,
#    673335,
#    675174,
#    675592,
#    677449,
#    678700,
#    679404,
#    681048,
#    681666,
#    682995,
#    683944,
#    684550,
#    685556,
#    689180,
#    689718,
#    690971,
#    690991,
#    691202,
#    691371,
#    691536,
#    692162,
#    693084,
#    693547,
#    693773,
#    696469,
#    700739,
#    700806,
#    702101,
#    702317,
#    702897,
#    705140,
#    705409,
#    708086,
#    709115,
#    710030,
#    710892,
#    711967,
#    712425,
#    712896,
#    713064,
#    713478,
#    714311,
#    714392,
#    714806,
#    714859,
#    715212,
#    715525,
#    716382,
#    716392,
#    716560,
#    716626,
#    718908,
#    720779,
#    720879,
#    722846,
#    723549,
#    724549,
#    726062,
#    726070,
#    729107,
#    729160,
#    729166,
#    729875,
#    730065,
#    732981,
#    733063,
#    733547,
#    737743,
#    739912,
#    742165,
#    742182,
#    742678,
#    743221,
#    744152,
#    745090,
#    745540,
#    746044,
#    746873,
#    748376,
#    750088,
#    750612,
#    752052,
#    752541,
#    752899,
#    753623,
#    756244,
#    756922,
#    760953,
#    761477,
#    761640,
#    761723,
#    762105,
#    766713,
#    766992,
#    767305,
#    768007,
#    770400,
#    776110,
#    779410,
#    780019,
#    783301,
#    788140,
#    790812,
#    791531,
#    792447,
#    794947,
#    795356,
#    796421,
#    796951,
#    797644,
#    797884,
#    798207,
#    801101,
#    804766,
#    806682,
#    807425,
#    807538,
#    808375,
#    810567,
#    812414,
#    813547,
#    813866,
#    814610,
#    815500,
#    817144,
#    817714,
#    821362,
#    821442,
#    821988,
#    822716,
#    822719,
#    822993,
#    826003,
#    826411,
#    829241,
#    829875,
#    830452,
#    832981,
#    833279,
#    833557,
#    834714,
#    836906,
#    837003,
#    837100,
#    837106,
#    837312,
#    838604,
#    845844,
#    846303,
#    849278,
#    851336,
#    852101,
#    852544,
#    853768,
#    854077,
#    856902,
#    858976,
#    860528,
#    860849,
#    860906,
#    860997,
#    861115,
#    861612,
#    861774,
#    861857,
#    862388,
#    862566,
#    863040,
#    863464,
#    864968,
#    865466,
#    868340,
#    868598,
#    869540,
#    871584,
#    872239,
#    872879,
#    874694,
#    875257,
#    875699,
#    876336,
#    878102,
#    878178,
#    878452,
#    879139,
#    879145,
#    879261,
#    879689,
#    881039,
#    881412,
#    881878,
#    882059,
#    883128,
#    884577,
#    885137,
#    885203,
#    889871,
#    890370,
#    890485,
#    890643,
#    892013,
#    895402,
#    896997,
#    897114,
#    897335,
#    897468,
#    897607,
#    897667,
#    897711,
#    899185,
#    899307,
#    899793,
#    902678,
#    903911,
#    904157,
#    905096,
#    905984,
#    908101,
#    909528,
#    909543,
#    910444,
#    910495,
#    913687,
#    914303,
#    916247,
#    916255,
#    916973,
#    917097,
#    919075,
#    919577,
#    919971,
#    920362,
#    920742,
#    920940,
#    921282,
#    922380,
#    922393,
#    925723,
#    925817,
#    927202,
#    927369,
#    929935,
#    929946,
#    930290,
#    930396,
#    930867,
#    931052,
#    931541,
#    931782,
#    931816,
#    932029,
#    935140,
#    935622,
#    939528,
#    941134,
#    941357,
#    941819,
#    941838,
#    944671,
#    945415,
#    945506,
#    945546,
#    947061,
#    947247,
#    948389,
#    949148,
#    951536,
#    953851,
#    953945,
#    953982,
#    954245,
#    954311,
#    954391,
#    954418,
#    954608,
#    954736,
#    954901,
#    959154,
#    962320,
#    962544,
#    962627,
#    964767,
#    965223,
#    965327,
#    968844,
#    970288,
#    970760,
#    971108,
#    971628,
#    973524,
#    973821,
#    975583,
#    976100,
#    976611,
#    976840,
#    977151,
#    977425,
#    977524,
#    978278,
#    979614,
#    980129,
#    980341,
#    980627,
#    981114,
#    981604,
#    982825,
#    987458,
#    988193,
#    991651,
#    992723,
#    992792,
#    992794,
#    995385,
#    995664,
#    996071,
#    996097,
#    996445,
#    997422,
#    999819,
#    1002605,
#    1002691,
#    1003258,
#    1005648,
#    1007442,
#    1007799,
#    1007999,
#    1010957,
#    1011483,
#    1011595,
#    1012052,
#    1012054,
#    1012124,
#    1012243,
#    1014488,
#    1014606,
#    1015655,
#    1016153,
#    1018681,
#    1018801,
#    1021171,
#    1021389,
#    1021678,
#    1024437,
#    1027952,
#    1028781,
#    1029439,
#    1030596,
#    1031763,
#    1032140,
#    1034148,
#    1034382,
#    1035377,
#    1035441,
#    1035494,
#    1035575,
#    1035876,
#    1039234,
#    1039433,
#    1039736,
#    1039764,
#    1043085,
#    1043107,
#    1043140,
#    1043406,
#    1043902,
#    1044781,
#    1046540,
#    1046614,
#    1046865,
#    1046874,
#    1047471,
#    1049664,
#    1050879,
#    1051709,
#    1051872,
#    1052058,
#    1054510,
#    1054516,
#    1054613,
#    1054703,
#    1054813,
#    1055122,
#    1055217,
#    ...]}}

# %%
addcharge_schema = {
  "definitions": {},
  "$schema": "http://json-schema.org/draft-07/schema#",
  "$id": "http://example.com/root.json",
  "type": [
    "array",
    "null"
  ],
  "title": "The Root Schema",
  "items": {
    "$id": "#/items",
    "type": [
      "object",
      "null"
    ],
    "title": "The Items Schema",
    "properties": {
      "addcharge_amount": {
        "$id": "#/items/properties/addcharge_amount",
        "type": ["number", "null"],
        "title": "The Addcharge_amount Schema"
      },
      "addcharge_type": {
        "$id": "#/items/properties/addcharge_type",
        "type": ["string", "null"],
        "title": "The Addcharge_type Schema"
      }
    },
      'additionalProperties': {"type": "string"}
  }
}

# %%
# expect_column_values_to_match_json_schema
batch.expect_column_values_to_match_json_schema('ADDCHARGE_DETAILS', addcharge_schema, mostly=0.8)
# Out:
# {'success': True,
#  'result': {'element_count': 2674621,
#   'missing_count': 2152143,
#   'missing_percent': 80.46534443571632,
#   'unexpected_count': 0,
#   'unexpected_percent': 0.0,
#   'unexpected_percent_nonmissing': 0.0,
#   'partial_unexpected_list': [],
#   'partial_unexpected_index_list': [],
#   'partial_unexpected_counts': [],
#   'unexpected_list': [],
#   'unexpected_index_list': []}}

# %% [markdown]
# ### 8. Determine if columns are unique per row
# - CASE_ID, TASK_ID
# - CASE_ID, TASK_ID, VENDOR_ID
# - CLAIM_ID

# %%
batch.expect_multicolumn_values_to_be_unique(column_list=['CASE_ID', 'TASK_ID'], result_format='SUMMARY',
                                            catch_exceptions=True, include_config=True)
# Out:
# {'success': True,
#  'result': {'element_count': 2674621,
#   'missing_count': 0,
#   'missing_percent': 0.0,
#   'unexpected_count': 0,
#   'unexpected_percent': 0.0,
#   'unexpected_percent_nonmissing': 0.0,
#   'partial_unexpected_list': [],
#   'partial_unexpected_index_list': [],
#   'partial_unexpected_counts': []},
#  'expectation_config': {'expectation_type': 'expect_multicolumn_values_to_be_unique',
#   'kwargs': {'column_list': ['CASE_ID', 'TASK_ID'],
#    'result_format': 'SUMMARY'}},
#  'exception_info': {'raised_exception': False,
#   'exception_message': None,
#   'exception_traceback': None}}

# %%
batch.expect_multicolumn_values_to_be_unique(column_list=['CASE_ID', 'TASK_ID', 'VENDOR_ID'], result_format='SUMMARY',
                                            catch_exceptions=True, include_config=True)
# Out:
# {'success': True,
#  'result': {'element_count': 2674621,
#   'missing_count': 0,
#   'missing_percent': 0.0,
#   'unexpected_count': 0,
#   'unexpected_percent': 0.0,
#   'unexpected_percent_nonmissing': 0.0,
#   'partial_unexpected_list': [],
#   'partial_unexpected_index_list': [],
#   'partial_unexpected_counts': []},
#  'expectation_config': {'expectation_type': 'expect_multicolumn_values_to_be_unique',
#   'kwargs': {'column_list': ['CASE_ID', 'TASK_ID', 'VENDOR_ID'],
#    'result_format': 'SUMMARY'}},
#  'exception_info': {'raised_exception': False,
#   'exception_message': None,
#   'exception_traceback': None}}

# %%
print(batch.expect_column_values_to_be_unique('CLAIM_ID', catch_exceptions=True))
# Out:
# {'success': True, 'result': {'element_count': 2674621, 'missing_count': 0, 'missing_percent': 0.0, 'unexpected_count': 0, 'unexpected_percent': 0.0, 'unexpected_percent_nonmissing': 0.0, 'partial_unexpected_list': []}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}

# %% [markdown]
# ### 9. Looking at column A to be greater than column B
# - ORIGINAL_CLAIM_SUBMITTED_DATE_UTC > SERVICE_DATE_UTC
# - ORIGINAL_CLAIM_APPROVED_DATE_UTC > ORIGINAL_CLAIM_SUBMITTED_DATE_UTC
# - MODIFIED_DATE_UTC > ADDPAY_APPROVED_DATE_UTC

# %%
batch.expect_column_pair_values_A_to_be_greater_than_B('ORIGINAL_CLAIM_SUBMITTED_DATE_UTC', 'SERVICE_DATE_UTC', 
                                                       mostly=0.99, ignore_row_if='either_value_is_missing', 
                                                       result_format='SUMMARY', catch_exceptions=True)
# Out:
# {'success': True,
#  'result': {'element_count': 2674621,
#   'missing_count': 3194,
#   'missing_percent': 0.11941878868071401,
#   'unexpected_count': 116,
#   'unexpected_percent': 0.004337063082956427,
#   'unexpected_percent_nonmissing': 0.004342248543568662,
#   'partial_unexpected_list': [['2019-10-27 04:00:00', '2019-10-28 01:01:47'],
#    ['2019-11-22 05:00:00', '2019-11-23 04:16:49'],
#    ['2019-11-18 05:00:00', '2019-11-18 14:47:05'],
#    ['2019-11-18 05:00:00', '2019-11-18 21:19:46'],
#    ['2019-11-08 00:29:51', '2019-11-08 05:00:00'],
#    ['2019-11-04 05:00:00', '2019-11-05 11:08:28'],
#    ['2019-11-16 05:00:00', '2019-11-16 09:39:48'],
#    ['2019-11-11 05:00:00', '2019-11-11 05:00:00'],
#    ['2019-11-04 05:00:00', '2019-11-04 13:27:36'],
#    ['2019-11-07 05:00:00', '2019-11-07 14:42:09'],
#    ['2019-11-04 05:00:00', '2019-11-06 00:01:14'],
#    ['2019-11-18 05:00:00', '2019-11-18 16:19:18'],
#    ['2019-11-23 05:00:00', '2019-11-23 07:38:28'],
#    ['2019-12-30 05:00:00', '2019-12-30 12:17:37'],
#    ['2019-12-07 05:00:00', '2019-12-07 14:31:11'],
#    ['2019-12-27 05:00:00', '2019-12-27 22:19:04'],
#    ['2019-12-23 05:00:00', '2019-12-23 13:14:04'],
#    ['2019-12-10 05:00:00', '2019-12-10 15:32:28'],
#    ['2019-11-26 05:00:00', '2019-11-26 17:08:21'],
#    ['2019-11-22 05:00:00', '2019-11-25 17:35:07']],
#   'partial_unexpected_index_list': [43734,
#    61133,
#    80628,
#    115625,
#    132355,
#    132999,
#    143250,
#    143533,
#    151747,
#    167999,
#    168106,
#    203150,
#    208294,
#    234180,
#    253739,
#    261829,
#    298318,
#    365366,
#    416941,
#    420637],
#   'partial_unexpected_counts': [{'value': ['2019-10-27 04:00:00',
#      '2019-10-28 01:01:47'],
#     'count': 1},
#    {'value': ['2019-11-04 05:00:00', '2019-11-04 13:27:36'], 'count': 1},
#    {'value': ['2019-11-04 05:00:00', '2019-11-05 11:08:28'], 'count': 1},
#    {'value': ['2019-11-04 05:00:00', '2019-11-06 00:01:14'], 'count': 1},
#    {'value': ['2019-11-07 05:00:00', '2019-11-07 14:42:09'], 'count': 1},
#    {'value': ['2019-11-08 00:29:51', '2019-11-08 05:00:00'], 'count': 1},
#    {'value': ['2019-11-11 05:00:00', '2019-11-11 05:00:00'], 'count': 1},
#    {'value': ['2019-11-16 05:00:00', '2019-11-16 09:39:48'], 'count': 1},
#    {'value': ['2019-11-18 05:00:00', '2019-11-18 14:47:05'], 'count': 1},
#    {'value': ['2019-11-18 05:00:00', '2019-11-18 16:19:18'], 'count': 1},
#    {'value': ['2019-11-18 05:00:00', '2019-11-18 21:19:46'], 'count': 1},
#    {'value': ['2019-11-22 05:00:00', '2019-11-23 04:16:49'], 'count': 1},
#    {'value': ['2019-11-22 05:00:00', '2019-11-25 17:35:07'], 'count': 1},
#    {'value': ['2019-11-23 05:00:00', '2019-11-23 07:38:28'], 'count': 1},
#    {'value': ['2019-11-26 05:00:00', '2019-11-26 17:08:21'], 'count': 1},
#    {'value': ['2019-12-07 05:00:00', '2019-12-07 14:31:11'], 'count': 1},
#    {'value': ['2019-12-10 05:00:00', '2019-12-10 15:32:28'], 'count': 1},
#    {'value': ['2019-12-23 05:00:00', '2019-12-23 13:14:04'], 'count': 1},
#    {'value': ['2019-12-27 05:00:00', '2019-12-27 22:19:04'], 'count': 1},
#    {'value': ['2019-12-30 05:00:00', '2019-12-30 12:17:37'], 'count': 1}]},
#  'exception_info': {'raised_exception': False,
#   'exception_message': None,
#   'exception_traceback': None}}

# %%
batch.expect_column_pair_values_A_to_be_greater_than_B('ORIGINAL_CLAIM_APPROVED_DATE_UTC', 
                                                       'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC',
                                                       mostly=0.99, ignore_row_if='either_value_is_missing', 
                                                       result_format='SUMMARY', catch_exceptions=True)
# Out:
# {'success': True,
#  'result': {'element_count': 2674621,
#   'missing_count': 66043,
#   'missing_percent': 2.4692470447214765,
#   'unexpected_count': 151,
#   'unexpected_percent': 0.005645659702813969,
#   'unexpected_percent_nonmissing': 0.005788594398940726,
#   'partial_unexpected_list': [['2019-10-16 14:39:34', '2019-11-15 05:00:00'],
#    ['2019-10-16 13:39:14', '2019-11-15 05:00:00'],
#    ['2019-12-17 05:10:42', '2019-12-17 05:10:42'],
#    ['2019-10-16 13:39:14', '2019-11-15 05:00:00'],
#    ['2019-10-16 13:39:14', '2019-11-15 05:00:00'],
#    ['2019-10-16 08:18:36', '2019-11-15 05:00:00'],
#    ['2019-10-16 13:39:14', '2019-11-15 05:00:00'],
#    ['2020-01-03 13:53:34', '2020-12-31 05:00:00'],
#    ['2019-12-15 05:01:23', '2019-12-15 05:01:23'],
#    ['2019-12-28 05:00:42', '2019-12-28 05:00:42'],
#    ['2020-01-03 13:53:34', '2020-12-31 05:00:00'],
#    ['2020-01-23 17:00:13', '2020-01-23 17:00:13'],
#    ['2020-01-01 05:14:15', '2020-01-01 05:14:15'],
#    ['2020-01-21 05:18:08', '2020-01-21 05:18:08'],
#    ['2020-01-03 13:53:34', '2020-12-31 05:00:00'],
#    ['2020-01-03 13:53:34', '2020-12-31 05:00:00'],
#    ['2020-01-03 13:53:34', '2020-12-31 05:00:00'],
#    ['2019-12-10 05:01:35', '2019-12-10 05:01:35'],
#    ['2019-12-03 17:01:17', '2019-12-03 17:01:17'],
#    ['2019-12-11 05:00:14', '2019-12-11 05:00:14']],
#   'partial_unexpected_index_list': [23824,
#    28101,
#    67430,
#    93802,
#    97354,
#    98439,
#    99350,
#    179071,
#    202605,
#    251124,
#    258736,
#    272666,
#    281170,
#    295319,
#    307419,
#    393698,
#    397883,
#    418420,
#    430306,
#    485865],
#   'partial_unexpected_counts': [{'value': ['2020-01-03 13:53:34',
#      '2020-12-31 05:00:00'],
#     'count': 30},
#    {'value': ['2019-10-16 13:39:14', '2019-11-15 05:00:00'], 'count': 19},
#    {'value': ['2019-10-16 14:39:34', '2019-11-15 05:00:00'], 'count': 10},
#    {'value': ['2019-10-16 08:18:36', '2019-11-15 05:00:00'], 'count': 2},
#    {'value': ['2019-11-01 04:00:12', '2019-11-01 04:00:12'], 'count': 1},
#    {'value': ['2019-11-14 05:00:37', '2019-11-14 05:00:37'], 'count': 1},
#    {'value': ['2019-11-22 05:00:39', '2019-11-22 05:00:39'], 'count': 1},
#    {'value': ['2019-12-03 17:01:17', '2019-12-03 17:01:17'], 'count': 1},
#    {'value': ['2019-12-10 05:01:35', '2019-12-10 05:01:35'], 'count': 1},
#    {'value': ['2019-12-11 05:00:14', '2019-12-11 05:00:14'], 'count': 1},
#    {'value': ['2019-12-15 05:01:23', '2019-12-15 05:01:23'], 'count': 1},
#    {'value': ['2019-12-17 05:10:42', '2019-12-17 05:10:42'], 'count': 1},
#    {'value': ['2019-12-28 05:00:42', '2019-12-28 05:00:42'], 'count': 1},
#    {'value': ['2020-01-01 05:14:15', '2020-01-01 05:14:15'], 'count': 1},
#    {'value': ['2020-01-03 13:53:41', '2020-12-31 05:00:00'], 'count': 1},
#    {'value': ['2020-01-21 05:18:08', '2020-01-21 05:18:08'], 'count': 1},
#    {'value': ['2020-01-23 17:00:13', '2020-01-23 17:00:13'], 'count': 1},
#    {'value': ['2020-02-07 05:12:05', '2020-02-07 05:12:05'], 'count': 1},
#    {'value': ['2020-02-10 05:00:42', '2020-02-10 05:00:42'], 'count': 1},
#    {'value': ['2020-02-13 05:10:30', '2020-02-13 05:10:30'], 'count': 1}]},
#  'exception_info': {'raised_exception': False,
#   'exception_message': None,
#   'exception_traceback': None}}

# %%
batch.expect_column_pair_values_A_to_be_greater_than_B('MODIFIED_DATE_UTC','ADDPAY_APPROVED_DATE_UTC',
                                                       or_equal=True,
                                                       ignore_row_if='either_value_is_missing', 
                                                       result_format='SUMMARY', catch_exceptions=True)
# Out:
# {'success': True,
#  'result': {'element_count': 2674621,
#   'missing_count': 2578267,
#   'missing_percent': 96.39747089400704,
#   'unexpected_count': 0,
#   'unexpected_percent': 0.0,
#   'unexpected_percent_nonmissing': 0.0,
#   'partial_unexpected_list': [],
#   'partial_unexpected_index_list': [],
#   'partial_unexpected_counts': []},
#  'exception_info': {'raised_exception': False,
#   'exception_message': None,
#   'exception_traceback': None}}

# %% [markdown]
# ### 8. Expecting columns to be certain data type

# %%
rule_df.dtypes
# Out:
# CASE_ID                                           int64
# TASK_ID                                            int8
# VENDOR_ID                                        object
# CLAIM_ID                                          int32
# VENDOR_ADDRESS_ID                               float64
# CLAIM_PO_NUMBER_ENTERED                         float64
# ORIGINAL_CLAIM_PAYMENT_AMOUNT                   float64
# ORIGINAL_CLAIM_STATUS_CODE                       object
# ORIGINAL_CLAIM_TYPE_CODE                         object
# SUBMITTED_CLAIM_AMOUNT                          float64
# SUBMITTED_TOW_MILES                             float64
# SUBMITTED_ENROUTE_MILES                         float64
# SUBMITTED_LABOR_HOURS                           float64
# SERVICE_ID                                       object
# WAS_AUDITED                                        bool
# ADDCHARGE_AMOUNT                                float64
# IS_CLAIM_APPROVED                                  bool
# ORIGINAL_CLAIM_APPROVED_PAYMENT                 float64
# ADDCHARGE_DETAILS                                object
# ADDCHARGE_COUNT                                   int16
# BASE_TOTAL_FROM_RATES                           float64
# ADDPAY_DETAILS                                   object
# ADDPAY_COUNT                                    float64
# ADDPAY_PAYMENT_AMOUNT                           float64
# ADDPAY_APPROVED_PAYMENT                         float64
# COMPLETE_APPROVED_PAYMENT                       float64
# IS_VCC                                             bool
# ORIGINAL_CLAIM_APPROVED_DATE_EASTERN     datetime64[ns]
# ORIGINAL_CLAIM_APPROVED_DATE_UTC         datetime64[ns]
# SERVICE_DATE_EASTERN                     datetime64[ns]
# SERVICE_DATE_UTC                         datetime64[ns]
# ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN    datetime64[ns]
# ORIGINAL_CLAIM_SUBMITTED_DATE_UTC        datetime64[ns]
# ADDPAY_APPROVED_DATE_EASTERN             datetime64[ns]
# ADDPAY_APPROVED_DATE_UTC                 datetime64[ns]
# ADDPAY_SUBMITTED_DATE_EASTERN            datetime64[ns]
# ADDPAY_SUBMITTED_DATE_UTC                datetime64[ns]
# MODIFIED_DATE_EASTERN                    datetime64[ns]
# MODIFIED_DATE_UTC                        datetime64[ns]
# dtype: object

# %%
for x, y in batch.dtypes.iteritems():
    print(x, y)
# Out:
# CASE_ID int64
# TASK_ID int8
# VENDOR_ID object
# CLAIM_ID int32
# VENDOR_ADDRESS_ID float64
# CLAIM_PO_NUMBER_ENTERED float64
# ORIGINAL_CLAIM_PAYMENT_AMOUNT float64
# ORIGINAL_CLAIM_STATUS_CODE object
# ORIGINAL_CLAIM_TYPE_CODE object
# SUBMITTED_CLAIM_AMOUNT float64
# SUBMITTED_TOW_MILES float64
# SUBMITTED_ENROUTE_MILES float64
# SUBMITTED_LABOR_HOURS float64
# SERVICE_ID object
# WAS_AUDITED bool
# ADDCHARGE_AMOUNT float64
# IS_CLAIM_APPROVED bool
# ORIGINAL_CLAIM_APPROVED_PAYMENT float64
# ADDCHARGE_DETAILS object
# ADDCHARGE_COUNT int16
# BASE_TOTAL_FROM_RATES float64
# ADDPAY_DETAILS object
# ADDPAY_COUNT float64
# ADDPAY_PAYMENT_AMOUNT float64
# ADDPAY_APPROVED_PAYMENT float64
# COMPLETE_APPROVED_PAYMENT float64
# IS_VCC bool
# ORIGINAL_CLAIM_APPROVED_DATE_EASTERN datetime64[ns]
# ORIGINAL_CLAIM_APPROVED_DATE_UTC datetime64[ns]
# SERVICE_DATE_EASTERN datetime64[ns]
# SERVICE_DATE_UTC datetime64[ns]
# ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN datetime64[ns]
# ORIGINAL_CLAIM_SUBMITTED_DATE_UTC datetime64[ns]
# ADDPAY_APPROVED_DATE_EASTERN datetime64[ns]
# ADDPAY_APPROVED_DATE_UTC datetime64[ns]
# ADDPAY_SUBMITTED_DATE_EASTERN datetime64[ns]
# ADDPAY_SUBMITTED_DATE_UTC datetime64[ns]
# MODIFIED_DATE_EASTERN datetime64[ns]
# MODIFIED_DATE_UTC datetime64[ns]

# %%
network_claims_data_types = dict(batch.dtypes.iteritems())

# %%
for key, val in network_claims_data_types.items():
    network_claims_data_types[key] = str(val)

# %%
network_claims_data_types
# Out:
# {'CASE_ID': 'int64',
#  'TASK_ID': 'int8',
#  'VENDOR_ID': 'object',
#  'CLAIM_ID': 'int32',
#  'VENDOR_ADDRESS_ID': 'float64',
#  'CLAIM_PO_NUMBER_ENTERED': 'float64',
#  'ORIGINAL_CLAIM_PAYMENT_AMOUNT': 'float64',
#  'ORIGINAL_CLAIM_STATUS_CODE': 'object',
#  'ORIGINAL_CLAIM_TYPE_CODE': 'object',
#  'SUBMITTED_CLAIM_AMOUNT': 'float64',
#  'SUBMITTED_TOW_MILES': 'float64',
#  'SUBMITTED_ENROUTE_MILES': 'float64',
#  'SUBMITTED_LABOR_HOURS': 'float64',
#  'SERVICE_ID': 'object',
#  'WAS_AUDITED': 'bool',
#  'ADDCHARGE_AMOUNT': 'float64',
#  'IS_CLAIM_APPROVED': 'bool',
#  'ORIGINAL_CLAIM_APPROVED_PAYMENT': 'float64',
#  'ADDCHARGE_DETAILS': 'object',
#  'ADDCHARGE_COUNT': 'int16',
#  'BASE_TOTAL_FROM_RATES': 'float64',
#  'ADDPAY_DETAILS': 'object',
#  'ADDPAY_COUNT': 'float64',
#  'ADDPAY_PAYMENT_AMOUNT': 'float64',
#  'ADDPAY_APPROVED_PAYMENT': 'float64',
#  'COMPLETE_APPROVED_PAYMENT': 'float64',
#  'IS_VCC': 'bool',
#  'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN': 'datetime64[ns]',
#  'ORIGINAL_CLAIM_APPROVED_DATE_UTC': 'datetime64[ns]',
#  'SERVICE_DATE_EASTERN': 'datetime64[ns]',
#  'SERVICE_DATE_UTC': 'datetime64[ns]',
#  'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN': 'datetime64[ns]',
#  'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC': 'datetime64[ns]',
#  'ADDPAY_APPROVED_DATE_EASTERN': 'datetime64[ns]',
#  'ADDPAY_APPROVED_DATE_UTC': 'datetime64[ns]',
#  'ADDPAY_SUBMITTED_DATE_EASTERN': 'datetime64[ns]',
#  'ADDPAY_SUBMITTED_DATE_UTC': 'datetime64[ns]',
#  'MODIFIED_DATE_EASTERN': 'datetime64[ns]',
#  'MODIFIED_DATE_UTC': 'datetime64[ns]'}

# %%
for col, typ in network_claims_data_types.items():
    print(batch.expect_column_values_to_be_of_type(col, typ, result_format='SUMMARY', catch_exceptions=True))
# Out:
# {'success': True, 'result': {'observed_value': 'int64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'int8'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'object_'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'int32'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'object_'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'object_'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'object_'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'bool_'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'bool_'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'object_'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'int16'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'object_'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'float64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'bool_'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}
# {'success': True, 'result': {'observed_value': 'datetime64'}, 'exception_info': {'raised_exception': False, 'exception_message': None, 'exception_traceback': None}}

# %% [markdown]
# ### Review the expectations
#
# Expectations that were true on this data batch were added. To view all the expectations you added so far about this data asset, do:

# %%
batch.get_expectation_suite()
# Out:
# 2020-02-24T12:38:40-0500 - INFO - 	128 expectation(s) included in expectation_suite. Omitting 3 expectation(s) that failed when last run; set discard_failed_expectations=False to include them. result_format settings filtered.
# {'data_asset_name': 'agero_dsa_pandas/default/network_claims',
#  'expectation_suite_name': 'warnings_2019Q4',
#  'meta': {'great_expectations.__version__': '0.8.8'},
#  'expectations': [{'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDCHARGE_AMOUNT'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDCHARGE_COUNT'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDCHARGE_DETAILS'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDPAY_APPROVED_DATE_EASTERN'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDPAY_APPROVED_DATE_UTC'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDPAY_APPROVED_PAYMENT'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDPAY_COUNT'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDPAY_DETAILS'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDPAY_PAYMENT_AMOUNT'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDPAY_SUBMITTED_DATE_EASTERN'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ADDPAY_SUBMITTED_DATE_UTC'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'BASE_TOTAL_FROM_RATES'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'CASE_ID'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'CLAIM_ID'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'CLAIM_PO_NUMBER_ENTERED'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'COMPLETE_APPROVED_PAYMENT'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'IS_CLAIM_APPROVED'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'IS_VCC'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'MODIFIED_DATE_EASTERN'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'MODIFIED_DATE_UTC'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_DATE_UTC'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_PAYMENT'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_PAYMENT_AMOUNT'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_STATUS_CODE'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_TYPE_CODE'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'SERVICE_DATE_EASTERN'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'SERVICE_DATE_UTC'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'SERVICE_ID'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'SUBMITTED_CLAIM_AMOUNT'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'SUBMITTED_ENROUTE_MILES'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'SUBMITTED_LABOR_HOURS'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'SUBMITTED_TOW_MILES'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'TASK_ID'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'VENDOR_ADDRESS_ID'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'VENDOR_ID'}},
#   {'expectation_type': 'expect_column_to_exist',
#    'kwargs': {'column': 'WAS_AUDITED'}},
#   {'expectation_type': 'expect_table_column_count_to_equal',
#    'kwargs': {'value': 39}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'CASE_ID'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'TASK_ID'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'VENDOR_ID'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'CLAIM_ID'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_PAYMENT_AMOUNT'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_STATUS_CODE'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_TYPE_CODE'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'SUBMITTED_CLAIM_AMOUNT'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'SERVICE_ID'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'WAS_AUDITED'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'IS_CLAIM_APPROVED'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_PAYMENT'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDCHARGE_COUNT'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'COMPLETE_APPROVED_PAYMENT'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'IS_VCC'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'SERVICE_DATE_EASTERN'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'SERVICE_DATE_UTC'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'MODIFIED_DATE_EASTERN'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'MODIFIED_DATE_UTC'}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'VENDOR_ADDRESS_ID', 'mostly': 0.995}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'CLAIM_PO_NUMBER_ENTERED', 'mostly': 0.998}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'SUBMITTED_TOW_MILES', 'mostly': 0.977}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'SUBMITTED_ENROUTE_MILES', 'mostly': 0.993}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'SUBMITTED_LABOR_HOURS', 'mostly': 0.937}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDCHARGE_AMOUNT', 'mostly': 0.194}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDCHARGE_DETAILS', 'mostly': 0.194}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'BASE_TOTAL_FROM_RATES', 'mostly': 0.651}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDPAY_DETAILS', 'mostly': 0.037}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDPAY_COUNT', 'mostly': 0.037}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDPAY_PAYMENT_AMOUNT', 'mostly': 0.037}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDPAY_APPROVED_PAYMENT', 'mostly': 0.037}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN',
#     'mostly': 0.976}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_DATE_UTC', 'mostly': 0.976}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN',
#     'mostly': 0.998}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC', 'mostly': 0.998}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDPAY_APPROVED_DATE_EASTERN', 'mostly': 0.035}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDPAY_APPROVED_DATE_UTC', 'mostly': 0.035}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDPAY_SUBMITTED_DATE_EASTERN', 'mostly': 0.037}},
#   {'expectation_type': 'expect_column_values_to_not_be_null',
#    'kwargs': {'column': 'ADDPAY_SUBMITTED_DATE_UTC', 'mostly': 0.037}},
#   {'expectation_type': 'expect_column_values_to_be_in_set',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_STATUS_CODE',
#     'value_set': ['AP',
#      'DP',
#      'FC',
#      'FP',
#      'HD',
#      'PC',
#      'PD',
#      'PJ',
#      'SP',
#      'VD']}},
#   {'expectation_type': 'expect_column_values_to_be_in_set',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_TYPE_CODE',
#     'value_set': ['OWN', 'VND']}},
#   {'expectation_type': 'expect_column_values_to_be_in_set',
#    'kwargs': {'column': 'SERVICE_ID',
#     'value_set': ['GOA',
#      'LOCK',
#      'Lock',
#      'NA',
#      'REPO',
#      'ROAD',
#      'Road',
#      'TOW',
#      'Tow',
#      'null',
#      'tow']}},
#   {'expectation_type': 'expect_column_values_to_be_json_parseable',
#    'kwargs': {'column': 'ADDCHARGE_DETAILS', 'mostly': 0.98}},
#   {'expectation_type': 'expect_column_values_to_be_json_parseable',
#    'kwargs': {'column': 'ADDPAY_DETAILS', 'mostly': 0.98}},
#   {'expectation_type': 'expect_column_values_to_match_json_schema',
#    'kwargs': {'column': 'ADDPAY_DETAILS',
#     'json_schema': {'definitions': {},
#      '$schema': 'http://json-schema.org/draft-07/schema#',
#      '$id': 'http://example.com/root.json',
#      'type': ['array', 'null'],
#      'title': 'The Root Schema',
#      'items': {'$id': '#/items',
#       'type': ['object', 'null'],
#       'title': 'The Items Schema',
#       'required': ['addpay_approved_date',
#        'addpay_approved_payment_amount',
#        'addpay_claim_id',
#        'addpay_is_approved',
#        'addpay_payment_amount',
#        'addpay_submitted_date',
#        'addpay_task_id',
#        'addpay_vendor_id',
#        'original_claim_amount_paid',
#        'original_claim_amount_requested',
#        'original_claim_id',
#        'original_claim_vendor_id',
#        'service_date'],
#       'properties': {'addpay_approved_date': {'$id': '#/items/properties/addpay_approved_date',
#         'type': ['string', 'null'],
#         'format': 'date-time',
#         'title': 'The Addpay_approved_date Schema',
#         'default': '',
#         'examples': ['2019-02-20T04:02:00'],
#         'pattern': '^(.*)$'},
#        'addpay_approved_payment_amount': {'$id': '#/items/properties/addpay_approved_payment_amount',
#         'type': ['number', 'null'],
#         'title': 'The Addpay_approved_payment_amount Schema',
#         'default': 0,
#         'examples': [27]},
#        'addpay_claim_id': {'$id': '#/items/properties/addpay_claim_id',
#         'type': ['number', 'null'],
#         'title': 'The Addpay_claim_id Schema',
#         'default': 0,
#         'examples': [88551584]},
#        'addpay_is_approved': {'$id': '#/items/properties/addpay_is_approved',
#         'type': ['boolean', 'null'],
#         'title': 'The Addpay_is_approved Schema',
#         'default': False,
#         'examples': [True]},
#        'addpay_payment_amount': {'$id': '#/items/properties/addpay_payment_amount',
#         'type': ['number', 'null'],
#         'title': 'The Addpay_payment_amount Schema',
#         'default': 0,
#         'examples': [27]},
#        'addpay_submitted_date': {'$id': '#/items/properties/addpay_submitted_date',
#         'type': ['string', 'null'],
#         'format': 'date-time',
#         'title': 'The Addpay_submitted_date Schema',
#         'default': '',
#         'examples': ['2019-02-19T00:00:00'],
#         'pattern': '^(.*)$'},
#        'addpay_task_id': {'$id': '#/items/properties/addpay_task_id',
#         'type': ['number', 'null'],
#         'title': 'The Addpay_task_id Schema',
#         'default': 0,
#         'examples': [2]},
#        'addpay_vendor_id': {'$id': '#/items/properties/addpay_vendor_id',
#         'type': ['string', 'null'],
#         'title': 'The Addpay_vendor_id Schema',
#         'default': '',
#         'examples': ['133573'],
#         'pattern': '^(.*)$'},
#        'original_claim_amount_paid': {'$id': '#/items/properties/original_claim_amount_paid',
#         'type': ['number', 'null'],
#         'title': 'The Original_claim_amount_paid Schema',
#         'default': 0.0,
#         'examples': [57.95]},
#        'original_claim_amount_requested': {'$id': '#/items/properties/original_claim_amount_requested',
#         'type': ['number', 'null'],
#         'title': 'The Original_claim_amount_requested Schema',
#         'default': 0,
#         'examples': [59]},
#        'original_claim_id': {'$id': '#/items/properties/original_claim_id',
#         'type': ['number', 'null'],
#         'title': 'The Original_claim_id Schema',
#         'default': 0,
#         'examples': [195082625]},
#        'original_claim_vendor_id': {'$id': '#/items/properties/original_claim_vendor_id',
#         'type': ['string', 'null'],
#         'title': 'The Original_claim_vendor_id Schema',
#         'default': '',
#         'examples': ['133573'],
#         'pattern': '^(.*)$'},
#        'service_date': {'$id': '#/items/properties/service_date',
#         'type': ['string', 'null'],
#         'format': 'date-time',
#         'title': 'The Service_date Schema',
#         'default': '',
#         'examples': ['2019-02-14T11:50:21'],
#         'pattern': '^(.*)$'}}}},
#     'mostly': 0.92}},
#   {'expectation_type': 'expect_column_values_to_match_json_schema',
#    'kwargs': {'column': 'ADDCHARGE_DETAILS',
#     'json_schema': {'definitions': {},
#      '$schema': 'http://json-schema.org/draft-07/schema#',
#      '$id': 'http://example.com/root.json',
#      'type': ['array', 'null'],
#      'title': 'The Root Schema',
#      'items': {'$id': '#/items',
#       'type': ['object', 'null'],
#       'title': 'The Items Schema',
#       'properties': {'addcharge_amount': {'$id': '#/items/properties/addcharge_amount',
#         'type': ['number', 'null'],
#         'title': 'The Addcharge_amount Schema'},
#        'addcharge_type': {'$id': '#/items/properties/addcharge_type',
#         'type': ['string', 'null'],
#         'title': 'The Addcharge_type Schema'}},
#       'additionalProperties': {'type': 'string'}}},
#     'mostly': 0.8}},
#   {'expectation_type': 'expect_multicolumn_values_to_be_unique',
#    'kwargs': {'column_list': ['CASE_ID', 'TASK_ID', 'VENDOR_ID']}},
#   {'expectation_type': 'expect_column_values_to_be_unique',
#    'kwargs': {'column': 'CLAIM_ID'}},
#   {'expectation_type': 'expect_column_pair_values_A_to_be_greater_than_B',
#    'kwargs': {'column_A': 'MODIFIED_DATE_UTC',
#     'column_B': 'ADDPAY_APPROVED_DATE_UTC',
#     'or_equal': True,
#     'ignore_row_if': 'either_value_is_missing'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'CASE_ID', 'type_': 'int64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'TASK_ID', 'type_': 'int8'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'VENDOR_ID', 'type_': 'object'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'CLAIM_ID', 'type_': 'int32'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'VENDOR_ADDRESS_ID', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'CLAIM_PO_NUMBER_ENTERED', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_PAYMENT_AMOUNT', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_STATUS_CODE', 'type_': 'object'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_TYPE_CODE', 'type_': 'object'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'SUBMITTED_CLAIM_AMOUNT', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'SUBMITTED_TOW_MILES', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'SUBMITTED_ENROUTE_MILES', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'SUBMITTED_LABOR_HOURS', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'SERVICE_ID', 'type_': 'object'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'WAS_AUDITED', 'type_': 'bool'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDCHARGE_AMOUNT', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'IS_CLAIM_APPROVED', 'type_': 'bool'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_PAYMENT',
#     'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDCHARGE_DETAILS', 'type_': 'object'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDCHARGE_COUNT', 'type_': 'int16'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'BASE_TOTAL_FROM_RATES', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDPAY_DETAILS', 'type_': 'object'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDPAY_COUNT', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDPAY_PAYMENT_AMOUNT', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDPAY_APPROVED_PAYMENT', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'COMPLETE_APPROVED_PAYMENT', 'type_': 'float64'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'IS_VCC', 'type_': 'bool'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_DATE_EASTERN',
#     'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_APPROVED_DATE_UTC',
#     'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'SERVICE_DATE_EASTERN', 'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'SERVICE_DATE_UTC', 'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_SUBMITTED_DATE_EASTERN',
#     'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ORIGINAL_CLAIM_SUBMITTED_DATE_UTC',
#     'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDPAY_APPROVED_DATE_EASTERN',
#     'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDPAY_APPROVED_DATE_UTC',
#     'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDPAY_SUBMITTED_DATE_EASTERN',
#     'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'ADDPAY_SUBMITTED_DATE_UTC',
#     'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'MODIFIED_DATE_EASTERN', 'type_': 'datetime64[ns]'}},
#   {'expectation_type': 'expect_column_values_to_be_of_type',
#    'kwargs': {'column': 'MODIFIED_DATE_UTC', 'type_': 'datetime64[ns]'}}],
#  'data_asset_type': 'Dataset'}

# %%
batch.save_expectation_suite()
# Out:
# 2020-01-31T18:26:29-0500 - INFO - 	64 expectation(s) included in expectation_suite. result_format settings filtered.

# %% [markdown]
# ### You created and saved expectations for at least one of the data assets.
#
# ### We will show you how to set up validation - the process of checking if new files of this type conform to your expectations before they are processed by your pipeline's code.
#
# ### Go to [integrate_validation_into_pipeline.ipynb](integrate_validation_into_pipeline.ipynb) to proceed.
